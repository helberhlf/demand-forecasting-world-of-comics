# %% [markdown]
# <font color="red">O SENHOR Deus-Todo-Poderoso, dou graças ao SENHOR por me doar mais um dia para respirar *"[...] respirar para viver"* (Eclesiastes 3.19), porque todos os dias é meu primeiro dia, o dia do amanhã só pertence ao SENHOR! Provérbios 27:1 *“Não presumas do dia de amanhã, porque não sabes o que ele trará.”*. *“Quem de vocês, por mais preocupado que esteja, pode acrescentar ao menos uma hora à sua vida.” (Mateus 6.27).* O SENHOR, na força da graça com o coração agradecido, sou eternamente grato ao SENHOR por me abençoar com uma família extraordinária em enormes circunstâncias me apoia durante esta extensa jornada de estudo (conhecimento).</font>
#
# ***
#
# *“Um resultado justo pode ser obtido apenas declarando e equilibrando completamente os fatos e argumentos em ambos os lados de cada questão.”* - Charles Darwin
#
#
# ***

# %% [markdown]
# ### <center>Demand Forecasting World of Comics</center>
#
# #### Previsão de demanda por brinquedos do mundo dos quadrinhos ao Longo do Tempo Para Otimizar Decisões de Logística
#
# Pergunta de negócio?
#
# > Qual é a previsão do total de vendas nas próximas 24 horas no futuro?

# %% [markdown]
# ### Objective

# %% [markdown]
# Objetivo é construir um modelo preditivo para prever demanda de vendas de toys de história em quadrinhos bom base em diverso indicadores usando séries temporais with Deep Learning.

# %% [markdown]
# Tudo bem! Vamos fingir que você acabou de ser contratado como **cientista de dados** por uma empresa do ramo varejista cuja o impacto é nas vendas do mundo das histórias em quadrinhos. Sendo assim, sua segunda tarefa é **construir um modelo que prever total de vendas nas próximas 24 horas da loja** com o objetivo de prever as decisões de Logística da empresa nas funções de demanda e oferta? Você tem acesso aos dados da loja de toys **desde 2018**. Proponho analisarmos juntos como você lidaria com isso.

# %% [markdown]
# ###  Challenge
#
# A  complexidade deste projeto reside em lidar com uma série temporal  multivariada, que tem diversas variáveis que interagem entre si ao longo  do tempo.

# %% [markdown]
# ### The Proposed Solution:
#
# *"Se você acha que uma arquitetura boa é cara, experimente uma arquitetura ruim."* - Brian Foote e Joseph Yoder
#
# Existe uma família de arquiteturas de redes neurais projetadas especificamente para este  tipo de (cénario) desafio: **Redes neurais Recorrentes**. Entre elas, a camada Long Short Term Memory (LSTM) and GRUs (Gated Recurrent Units) tem sido muito popular em aplicabilidade em systems de Inteligência Artificial. Essas famílias de arquiteturas são projetadas especificamente para modelagem de séries temporais  multivariadas de alta dimensão, oferecendo maior precisão nas previsões  ao capturar relações complexas e padrões temporais.
#
# Resultados Esperados:
#
# - Um modelo preditivo robusto que possa prever a demanda de vendas mais assertivas.
#
# - Diferentes horizontes de previsão.
#
# - Relatório detalhado que explique a importância de diferentes variáveis  nos resultados previstos, ajudando na tomada de decisões estratégicas.
#
# - Taxa de erro extremamente baixa
#
# Benefícios para o Negócio:
#
# - Aumento da eficiência operacional por meio de um planejamento de oferta e demanda mais preciso.
#
# - Otimização de tarefas, redução de gastos, controle e coordenação de trabalho em tarefas de tomadas decisões com base nas previsões.
#
# - Melhoria da agilidade da empresa, permitindo respostas mais rápidas a  mudanças no mercado e salto exponencial no lucro (anual, mensal e principalmente diário),
#
# Após a conclusão do projeto, a empresa não só terá poderosas ferramentas de inteligência artificial para otimizar seus processos de oferta e demanda, mas também ganhará uma vantagem estratégica significativa no mercado varejista cada vez mais competitivo.

# %% [markdown]
# ### Objectives and Key Results (OKRs)
#
#
# De acordo (SALIM.I; MICHAEL.S; YURI.V, 2018) eles afirmam que muitas **Organizações Exponeciais (ExOs)** estão adotando o método dos **Objetivos e Resultados-Chave (OKR – Objectives and Key Results).** Inventado na Intel pelo CEO Andy Grove e levado ao Google pelo capitalista de risco John Doerr, em 1999, os OKRs acompanham as metas individuais, das equipes e da empresa e expõem os resultados de uma forma aberta e transparente. Em High Output Management, o manual altamente conceituado de Grove, ele introduziu os OKRs como a resposta a duas perguntas simples.
#
# - 1. Aonde quero ir? (*Objetivos.*)
# - 2. Como sei que estou chegando lá? (*Resultados-chave para garantir que o progresso esteja ocorrendo.*)
#
# Além da Intel e do Google, outras empresas de rápido crescimento que utilizam o sistema incluem LinkedIn, Zynga, Oracle, Twitter e Facebook.
#
# Além do mais, os autores ressaltar que um programa de OKRs, como o próprio nome sugere, opera ao longo
# de dois trajetos. **Um objetivo, por exemplo, poderia ser "aumentar as vendas em 25%", juntamente com "formar duas parcerias estratégicas" e "conduzir uma campanha de AdWords como sendo os resultados-chave
# desejados. Os OKRs envolvem foco, simplicidade, ciclos de feedback (mais) curtos e transparência. Como resultado, insights e melhorias são mais fáceis de ver e implementar. Em contraste, a complexidade, o sigilo e objetivos amplos tendem a impedir o progresso, muitas vezes resultando
# em consequências imprevisíveis.**
#
# Além disso, os OKRs também são indicadores importantes para as corporações, embora os OKRs sejam mais importantes em novas startups, onde altas taxas de crescimento de contratações exigem um ciclo de feedback mais curto. Mas as grandes empresas também precisam deles porque os OKRs:
#
# - Incentivam o pensamento disciplinado (grandes metas virão à tona);
#
# - Aumentam a comunicação eficaz (todos aprendem o que é importante);
#
# - Estabelecem indicadores para medir o progresso (mostram em que ponto a empresa se encontra);
#
# - Focalizam no esforço (e, assim, sincronizam a organização). Incentivam o pensamento disciplinado (grandes metas virão à tona);
#
# ---

# %% [markdown]
# ### <center> Metrics and Results Achieved</center>

# %% [markdown]
#     Model BI-LSTM with Triangular structure recurrent layers using method Seq2Seq
#
# #### Results on test data
#
#
# ![image.png](attachment:5da57f9e-4fe0-4392-a446-d9db6611c5b2.png)
#
# > Source: Deep Learning with Python, 2ed
#
# ![image.png](attachment:8cf89cbd-cb65-4c03-a72b-25c8f7aa1019.png)

# %% [markdown]
# Em síntese, os resultados apresentados confirmar que temos um modelo que demostrar **resultados plausíveis** de acordo com dados utilizados, ou seja, *“Todos os modelos estão errados, mas alguns modelos são úteis.”* - George Box. Portanto, o pesquisador do projeto orienta aos executivos **nível C** como: CEO, CMO,CTO, CFO etc., e o novo Chief Data Officer (CDO) que realiza o deploy do modelo.
#
# ### OKR's de Endurance
#
# De acordo com esses resultados alcançáveis, este modelo econtrou um erro MAE em teste **em R$ 389.80 em média**, corresponde valor médio do todal de vendas por dia. Porém, se você sempre assumir que **total de vendas por dia de toys** será a mesma para o próximo dia, você estará errado **389.90 reais em média**. Além disso, esse é um valor relativamente (seriamente) pequeno se comparado à média do total de vendas por dia, que é de **9,842.21 reais**
#
#
# Acrescentando-se que, com base nesses resultados alcançáveis, este modelo comprovar que MAPE (Erro percentual médio absoluto) afirma que as previsões do nosso modelo estão, **em média 4,4% abaixo do valor real**. Em termos mais formais, isso nos diz que o erro percentual absoluto médio entre as médias de vendas previstas pelo modelo e as vendas reais é de **4,4%**. Assim como, MAPE indicará  o quão longe as previsões do modelo estão de suas saídas correspondentes em média.
#
# ---

# %% [markdown]
# ### About Dataset
#
# Este conjunto de dados contém uma base de dados de um cliente fictício sobre vendas de uma Loja de Brinquedos de Quadrinhos.

# %% [markdown]
# ###  Data dictionary
#
# O modelo deve receber como entrada os seguintes dados:
#
# #### <center>Consumer data:</center>
#
# | |Variável | Descrição|
# |---|:-------------|:-----------|
# | 1 |**ID:**|Identificador único de um consumidor|
# | 2 |**City:**|Cidade/localidade onde um consumidor fez a compra|
# | 3 |**State:**| Unidade Federativa onde um consumidor fez a compra)|
# | 4 |**DateOfBirth:**|Data de nascimento de um consumidor|
# | 5 |**Sex:**| Sexo de um consumidor |
#
#
# #### <center>Store details:</center>
#
# | |Variável | Descrição|
# |---:|:-------------|:-----------|
# | 1 |**ID:**|Identificador único de uma loja|
# | 2 |**City:**|Cidade/localidade de uma loja compra|
# | 3 |**State:**|  Unidade Federativa de uma loja |
#
#
# #### <center>Product data:</center>
#
#
# | |Variável | Descrição|
# |---:|:-------------|:-----------|
# | 1 |**ID:**|Identificador único de um produto|
# | 2 |**Name:**|Nome de um produto|
# | 3 |**Size:**|Tamanho de um produto (P,M,G ...)|
#
#
# #### <center>Sales data:</center>
#
# | |Variável | Descrição|
# |---:|:-------------|:-----------|
# | 1 |**ID:**|Identificador único de uma venda|
# | 2 |**ProductID:**|Identificador único de um produto|
# | 3 |**ClientID:**|Identificador único de um cliente|
# | 4 |**Discount:**|Desconto aplicado em uma venda|
# | 5 |**UnitPrice:**|Preço unitário de um produto vendido|
# | 6 |**Quantity:**|Quantidade de produto vendido em uma venda|
# | 7 |**StoreID:**|Identificador único de uma loja|
# | 8 |**StoreID:**|Data de uma venda|

# %% [markdown]
# ### <center>Contents</center>

# %% [markdown]
# ### 1. The end-to-end pipeline of an Machine Learning project
#
# ### 2. Exploratory data analysis & Data preprocessing
#
# ### 3. Feature Selection
#
# ### 4.  Train/Test Split
#
# ### 5. Predictive Modeling
#
# ### 6. Recurrent Neural Networks
#
# ---

# %% [markdown]
# ### Importing Necessary Modules and Functions
#
# Este projeto usa várias bibliotecas. Isso pode ser bom ou ruim. Algumas dessas bibliotecas podem ser difíceis de instalar ou podem entrar em conflito com versões de outras bibliotecas.
#
# Existem duas opções principais para instalar bibliotecas em Python. Uma delas é usa pip (um acrônimo para Pip Installs Python, ou Pip installs Python), uma ferramenta que vem com o Python e a outra opção é usar o Anaconda (https://anaconda.org).
#
# Inicializaremos o projeto com todas as bibliotecas necessárias para atingir objetivos desejados.
#
# ---

# %% [markdown]
# This project requires Python 3.7 or higher:

# %%
# Importing libraries needed for Operating System Manipulation in Python
import os, sys
from platform import python_version
from packaging import version

assert sys.version_info >= (3, 7)

# %% [markdown]
# And TensorFlow ≥ 2.8:

# %%
# Set environment variable to silence TF messages
# %env TF_CPP_MIN_LOG_LEVEL=3
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
# Import libraries TensorFlow e Keras
import tensorflow as tf

# Importing the progress bar
from tqdm.keras import TqdmCallback

assert version.parse(tf.__version__) >= version.parse("2.8.0")

# Set environment variable to silence TF messages
# %env TF_CPP_MIN_LOG_LEVEL=3
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
# Importing library for manipulation and exploration of datasets.
import numpy as np
import pandas as pd
import sidetable
from ydata_profiling import ProfileReport

# Importing library for manipulation time
from pathlib import Path
from time import strftime
from pandas.tseries.offsets import DateOffset
import datetime

# Importing functions auxiliary
from functions import functions_aux

# Importing functions to calculate some statistics.
from statistical_calculations import stats_calc

# Importing functions for dataset manipulation for time series
from time_series import ts

# Imports for time series analysis and modeling
import statsmodels.api as sm
from scipy import stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import(
    plot_acf, plot_pacf
)

# Import functions for custom transformations
from custom_transformers import transformer

# Importing pipelines
from sklearn.pipeline import  Pipeline
from sklearn.compose import(
    ColumnTransformer,
)

# Importing classes and libraries needed for the data pre-processing step.
from sklearn import preprocessing
from sklearn.preprocessing import (
    MinMaxScaler,StandardScaler
)

# Importing libraries needed for predictive modeling, ML and DL
from algorithms import dl_and_ml


# Importing class, to load and save predictive models in external files.
import pickle,joblib

# Importing auxiliary graphics
from graphics import graphic 


# For Graph Rendering using matplotlib 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as m

# Formatting the graphics output
plt.style.use('fivethirtyeight')
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend',fontsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
m.rcParams['text.color'] = 'k'

# Configuring how many rows and columns will be shown in the notebook
from IPython.display import display, Image
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# To hide Future Warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.simplefilter(action = 'ignore', category = FutureWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# ### System and Libraries Report
#
# A função a seguir confirmar as informações de hardware, sistema e versões da bibliotecas usadas neste projeto

# %%
# This module is used to record versions of other modules used in this jupyter.
print("=" *40)
# %reload_ext watermark
# %watermark -a "Helber" --iversions

# Python Language Version
print('Python Language Version Used In This Jupyter Notebook:', python_version())
functions_aux.info_system()
# Out:
# ...
# Author: Helber
#
# matplotlib : 3.6.3
# sklearn    : 0.0.post1
# scipy      : 1.11.3
# sidetable  : 0.9.1
# packaging  : 21.3
# sys        : 3.9.7 (default, Sep 16 2021, 13:09:58)
# [GCC 7.5.0]
# tensorflow : 2.11.0
# numpy      : 1.22.4
# pandas     : 1.5.3
# statsmodels: 0.13.2
# joblib     : 1.0.1
#
# Python Language Version Used In This Jupyter Notebook: 3.9.7
# ======================================== System Information ========================================
# System: Linux
# Release: 5.15.0-79-generic
# Version: #86~20.04.2-Ubuntu SMP Mon Jul 17 23:27:17 UTC 2023
# Machine: x86_64
# ======================================== CPU Info ========================================
# Physical cores: 6
# Total cores: 12
# Max Frequency: 4800.00Mhz
# Min Frequency: 800.00Mhz
# ======================================== Memory Information ========================================
# Total: 31.18GB

# %% [markdown]
# ---
#
# ### 1. The end-to-end pipeline of an Machine Learning project

# %% [markdown]
# ### 1.1. An overview of the end-to-end pipeline

# %% [markdown]
# Um pipeline de ML é uma sequência de etapas para conduzir um projeto de ML. Essas etapas seguem:

# %% [markdown]
# - **Definicão do problema e coleta de dados:** Define objetivo do problema em termo de negócios como um problema de ML e colete os dados de que você precisa.
#
# - **Pré-processamento de dados e engenharia de recursos:** Processar os dados em um formato adequado que
# pode ser inserido nos algoritmos de ML.Assim como,selecionar ou gerar recursos relacionados
# para a saída de destino para melhorar o desempenho dos algoritmos.Além disso, essa etapa geralmente é realizada explorando primeiro o conjunto de dados para ter uma noção de suas características. As operações devem acomodar os algoritmos de ML específicos que você está considerando.
#
# - **Seleção de algoritmo de ML:** Selecione algoritmos de ML apropriados para a tarefa que você
# gostaria de testar, com base em seu conhecimento prévio do problema e em sua
# experiência.
#
# - **Treinamento e avaliação do modelo:** Aplique o algoritmo (ou algoritmos) de ML selecionado
# para treinar um modelo de ML com seus dados de treinamento e avaliar seu desempenho em
# o conjunto de dados de validação.
#
# - **Ajuste de hiperparâmetros:** Tente alcançar um melhor desempenho iterativamente
# ajustando os hiperparâmetros do modelo.
#
# - **Implantação de serviços e monitoramento de modelos:** Implante a solução final de ML e monitore seu desempenho para que você possa manter e melhorar o pipeline continuamente.
#
# Dessa forma, como resultado você pode ver, um projeto de ML é um processo humano em loop. Bem como, iniciando com definnição do problema e coleta de dados, assim o pipeline envolve várias etapas de processamento de dados, que normalmente acontecem de forma assíncrona conforme a figura a seguir.
#
# ![image.png](attachment:f1930739-ed3f-4422-9bd7-11a02294cc53.png)
#
# > Source: (QINGQUAN.S; HAIFENG.J; X.HU, 2022)
#
# A primeira coisa que você precisa fazer em qualquer projeto de ML é define o problema e coletar os dados correspondentes.Assim, a definição do problema exige que você especifique as entradas e saídas do modelo de ML. No problema de vendas de video games, as entradas são conjunto de características que descrevem os jogos. Recomendo o livro Automated Machine Learning in Action para saber mais sobre todos esses fluxos de pipelines.

# %% [markdown]
# ### 2. Exploratory data analysis & Data preprocessing

# %% [markdown]
# Em primeira análise, o próximo passo é fazer algum pré-processamento para transformar os dados em um formato adequado para alimentar os algoritmos de ML. O procedimento geralmente envolve a etapa de análise exploratória de dados (EDA) com base em suposições anteriores ou perguntas sobre os dados.Dessa forma, a EDA pode nos ajude a nos familiarizar com o dataset e obter mais informações sobre ele, para permitir uma melhor preparação de dados. Assim como, algumas perguntas frenquente incluem as seguintes:
#
# - Quais são os tipos de dados dos valores em cada recurso? São strings ou outras
# objetos que podem ser usados em etapas posteriores no pipeline ou precisam ser Transformado?
#
# - Quantos valores distintos cada variável possui? São valores numéricos, valores categóricos, ou outra coisa?
#
# - Quais são as escalas e estatísticas básicas de cada variável? Podemos ganhar algum
# insights visualizando a distribuição dos valores ou correlações entre eles?
#
# - Há valores ausentes nos dados? Em caso afirmativo, temos que removê-los ou preencher
# com alguma abordagem de imputação?
#
# Diante disso, na prática dados de diferentes formatos geralmente requerem técnicas de pré-processamento de dados personalizados conforme o seu formato e características, de acordo com os problemas que nos interessam que estamos trabalhando  para modelos de ML e assim por diante. Este é geralmente um processo empírico heurístico, resultando na proposta de várias operações ad hoc. Na seção a seguir mostra o processo da análise exploratória e pré-processamento de dados.Mas antes disso, precisamos carregar o conjunto de dados ou dataset.

# %% [markdown]
# ### 2.1. Load Data

# %%
# Loading the data train with pandas

# %time
df     = pd.read_excel('dataset/df.xlsx',skiprows = range(0, 4))
client = pd.read_csv('dataset/client.csv')
prod   = pd.read_csv('dataset/prod.csv')
store  = pd.read_csv('dataset/store.csv')
sales  = pd.read_csv('dataset/sales.csv')

# Drop columns index
df.drop(df.columns[[0,1]], axis=1, inplace=True)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.29 µs

# %% [markdown]
# ### 2.1. Data set overview
#
# Iniciaremos o desenvolvimento com uma visualização mais sofisticada para obter uma visão completa dataset, é por meio da biblioteca **pandas-profiling** inclui um relatório de perfil. **Dessa forma, esse relatório sintetizará os tipos das colunas e permitirá que você visualize os detalhes das estatísticas dos quantis, as estatísticas descritivas, histogramax, os valores comuns e os valores extremos (outliers).**
#
# Portanto, com base nas quatro perguntas mencionadas na seção anterior, realizaremos um pré-processamento preliminar nos dados dessas perguntas, assim:
#
# - Qual são os tipos de dados em cada recurso?
#
# - Quantos valores distintos cada recurso tem no dataset?
#
# - Quais são a escala e as estatísticas básicas de cada recurso?
#
# - Há valores ausentes e duplicados contidos nos dados?

# %% [markdown]
# Este relatório mostrará muitas informações importantes no conjunto de dados e, à medida que desenvolveremos o projeto, seguiremos grande parte do relatório como um guia para cada etapa do projeto, sempre referindo-se o possível à sua seção de análise. Portanto, o código a seguir mostra os estágios iniciais do projeto.

# %%
# View the first five rows of the dataframe
df.head()
# Out:
#                                  ID                          ProductID  ClientID  Discount  UnitPrice  Quantity  StoreID       Date
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3     14001      0.08      249.2         1        4 2018-12-10
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93     14001      0.10      162.4         1        4 2019-04-25
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381     14001      0.10      194.6         1        4 2019-07-17
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33     14002      0.10      201.6         2        1 2018-04-10
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363     14002      0.10      406.0         1        1 2019-01-21

# %%
# convert column names to lowercase
df.columns = df.columns.str.lower()

# Create a profile report
df_report = ProfileReport(df, title="Comic Toy Story, world of comics report")

# Function object call
#df_report.to_notebook_iframe()

# create copy dataframe
df_cp = df.copy()

# Remove  as colunas indesejadas
unwanted_columns = ['id','clientid','productid']
df.drop(unwanted_columns, axis = 1, inplace = True, errors = 'ignore')

# %% [markdown]
# ### 2.2. Feature engineering
#
# A engenharia de atributos é a 'arte' de formular recursos úteis a partir de
# dados existentes seguindo o destino a ser aprendido e o modelo de ML.
#
# Envolve transformar dados em formas que melhor se relacionem com o alvo
# a ser aprendido. Quando bem feita, a Engenharia de Atributos pode aumentar o
# valor dos dados existentes e melhorar o desempenho dos modelos de Machine
# Learning. Por outro lado, usar recursos ruins pode exigir que você construa
# modelos muito mais complexos para atingir o mesmo nível de desempenho.
#
#
# Essa é a razão pela qual a engenharia de atributos encontrou seu lugar como
# uma etapa indispensável no pipeline de ML. No entanto,
# quando se trata de aplicar esse conceito, não há um método rígido e rápido ou
# estrutura teórica e é por isso que esta é uma das etapas mais complexas dentro do
# processo de Ciência de Dados, sendo uma das mais importantes para uma análise
# mais precisa e modelos de Machine Learning menos propensos a erros.
#
# Em outras palavras, a **engenharia de atributos é uma técnica usada para criar novas variáveis com base em variáveis existentes, a fim de melhorar o desempenho dos modelos de ML.**

# %% [markdown]
# Conforme observamos os conceitos mencionados acima, o código a seguir captura a experiência de combinar atributos para entender o preço final de venda de um ou mais brinquedos.

# %% [markdown]
# Em poucas palavras, uma  série  temporal  é  um  conjunto  sequencial  de  pontos  de  dados,  medido  tipicamente  em tempos sucessivos, em outras termos, a partir do comportamento passado da série procuramos inferir seu provável comportamento futuro.

# %%
# Ordem cronológica da série
df = df.sort_values('date').reset_index(drop=True)

# Combination of attributes
df['sales_amount'] = df.unitprice * df.quantity
df['sales_discount'] = df.sales_amount * df.discount
df['final_sales_price'] = df.sales_amount - df.sales_discount

# View combination
df.head()
# Out:
#    discount  unitprice  quantity  storeid       date  sales_amount  sales_discount  final_sales_price
# 0       0.1      156.8         1        1 2018-03-01         156.8           15.68             141.12
# 1       0.1      210.0         1        4 2018-03-01         210.0           21.00             189.00
# 2       0.1      161.0         2        7 2018-03-01         322.0           32.20             289.80
# 3       0.1      233.8         1        2 2018-03-01         233.8           23.38             210.42
# 4       0.1      233.8         1        3 2018-03-01         233.8           23.38             210.42

# %% [markdown]
# ### 2.2.1. Date decomposition for serie

# %% [markdown]
# A implementação da função a seguir faz a decomposição da série temporal por, ano, mês, semana, dia e hora sobre a demanda de vendas de toys.

# %%
# Function call, time series decomposition
ts_decomp= ts.decomposition(df,'date','final_sales_price')

# View decomposition
ts_decomp.head()
# Out:
#             discount  unitprice  quantity  storeid       date  sales_amount  sales_discount  final_sales_price  total_sales_per_year  total_sales_per_month  total_sales_per_week  total_sales_per_day  total_sales_per_hour  avg_sales_per_year  avg_sales_per_month  avg_sales_per_week  avg_sales_per_day  avg_sales_per_hour
# date
# 2018-03-01       0.1      156.8         1        1 2018-03-01         156.8           15.68             141.12                   NaN              248866.38                   NaN              5295.78               5295.78                 NaN           190.848451                 NaN         182.613103          182.613103
# 2018-03-01       0.1      210.0         1        4 2018-03-01         210.0           21.00             189.00                   NaN              248866.38                   NaN              5295.78               5295.78                 NaN           190.848451                 NaN         182.613103          182.613103
# ...

# %%
# Checking for duplicate records.
print(f'Values duplicated: {ts_decomp.duplicated().sum()}')
# Out:
# Values duplicated: 6397

# %% [markdown]
# O padrão drop_duplicates é manter a primeira ocorrência de uma linha duplicada e descartar o restante. Podemos controlar esse comportamento usando o parâmetro keep. Assim como, vamos obter as vendas da data da última ocorrência.
#
# Recomendo o livro Machine Learning with Python Cookbook 1E,  para saber mais sobre Data Wrangling

# %%
# Drop duplicates

#df_drop_dup=ts_decomp.drop_duplicates(subset=['date'],keep='last')
df_drop_dup=ts_decomp.drop_duplicates(subset='total_sales_per_day')

# Function calls to calculate the differences
functions_aux.summary_quick_in_between_datasets(ts_decomp,df_drop_dup)
# Out:
# First dataset, get the number of rows and columns: (32753, 18)
# Get the number of elements: 589554
#
# First dataset, get the number of rows and columns: (672, 18)
# Get the number of elements: 12096
# ----------------------------------------------------------------------
# Difference between datasets in rows: 32081 and columns: 0

# %%
# Check if there values missing dataset
df_drop_dup.stb.missing(clip_0=True, style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3f7e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f7e5_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_3f7e5_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_3f7e5_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f7e5_level0_row0" class="row_heading level0 row0" >total_sales_per_year</th>
#       <td id="T_3f7e5_row0_col0" class="data row0 col0" >670</td>
#       <td id="T_3f7e5_row0_col1" class="data row0 col1" >672</td>
#       <td id="T_3f7e5_row0_col2" class="data row0 col2" >99.70%</td>
#     </tr>
#     <tr>
#       <th id="T_3f7e5_level0_row1" class="row_heading level0 row1" >avg_sales_per_year</th>
#       <td id="T_3f7e5_row1_col0" class="data row1 col0" >670</td>
#       <td id="T_3f7e5_row1_col1" class="data row1 col1" >672</td>
# ...

# %% [markdown]
# Observe agora que, número grande de **valores nan** é realmente intratável (pelo menos, em um sentido amplo) mesmo quando a variável de dados é dividida em subvariáveis. Portanto, escolheremos o método mais viável, que é excluir essas variáveis do dataset.
#
# #### Observação
#
# **A maioria dos algoritmos Machine Learnign (ML) não pode funcionar com valores NAN.** Existe diversas formas de tratar valores NAN, como facilmente podemos utiliza
# os métodos já disponível como: **drop() e fillna() do DataFrame**, bem como, cada método desse tem sua característica específica de validação do tratamento.
#
#
# A remoção é uma boa opção se o conjunto de dados for suficientemente grande a ponto que a eliminação de alguns registros não afetar as conclusões. Outra boa razão para o uso da remoção seria se os valores discrepantes fossem tão extremos que distorcessem os resultados a ponto de serem geradas conclusões totalmente
# inapropriadas.

# %%
# Drop on column axis with nan values
df_dropna=df_drop_dup.dropna(subset=["total_sales_per_day"])

# Analyzing if there are missing values in the dataset
df_dropna.stb.missing(style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_50993">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50993_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_50993_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_50993_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50993_level0_row0" class="row_heading level0 row0" >avg_sales_per_year</th>
#       <td id="T_50993_row0_col0" class="data row0 col0" >670</td>
#       <td id="T_50993_row0_col1" class="data row0 col1" >672</td>
#       <td id="T_50993_row0_col2" class="data row0 col2" >99.70%</td>
#     </tr>
#     <tr>
#       <th id="T_50993_level0_row1" class="row_heading level0 row1" >total_sales_per_year</th>
#       <td id="T_50993_row1_col0" class="data row1 col0" >670</td>
#       <td id="T_50993_row1_col1" class="data row1 col1" >672</td>
# ...

# %%
# Remove todas as colunas indesejadas
unwanted_columns = ['avg_sales_per_year','total_sales_per_year',
                    'total_sales_per_month','avg_sales_per_month',
                    'total_sales_per_week','avg_sales_per_week']
df_dropna.drop(unwanted_columns, axis = 1, inplace = True, errors = 'ignore')

# Checking for duplicate records.
print(f'Values duplicated: {df_dropna.duplicated().sum()}')
# Out:
# Values duplicated: 0

# %% [markdown]
# ### 2.2.1.1. Simple Moving Average - SMA and Moving Standard Deviation - MSD
#
# Simple Moving Average (SMA) é um cálculo usado para analisar dados de séries temporais
# ao longo de um período de tempo especificado. **É chamada de "média móvel" porque à medida
# que novos pontos de dados se tornam disponíveis, os cálculos mais antigos são descartados e
# novos são adicionados, então a "média" literalmente "move" ao longo do tempo.**
#
# A SMA é calculada somando-se um número de pontos de dados e então dividindo-se pelo
# número de pontos de dados nesse conjunto. Por exemplo, uma SMA de 5 dias para o preço de toys seria calculada somando-se os preços de final_sales_price dos últimos 5 dias e dividindo se por 5.
#
# Além disso, uma das principais utilidades da SMA é que ela **suaviza as flutuações de curto prazo,
# ajudando o analista a identificar tendências de longo prazo.** No entanto, ela tem uma
# desvantagem significativa: ao suavizar os dados, ela também pode introduzir um atraso, o que
# significa que as mudanças de tendência na SMA serão observadas depois de já terem ocorrido
# nos dados originais.
#
# Em síntese, as SMA são frequentemente usadas em análises financeiras e técnicas para indicar
# tendências de preços de ações, forex ou outros ativos financeiros. Elas também podem ser
# usadas em outras disciplinas para suavizar qualquer tipo de dados de séries temporais
#
# ---
#
#
# O Moving Standard Deviation (MSD), ou Desvio Padrão Móvel, **é uma medida de
# volatilidade que muda ao longo do tempo.** Assim como a média móvel simples (SMA), é calculado
# ao longo de uma janela de tempo especificada, mas, em vez de calcular a média dos pontos de
# dados, calcula-se o desvio padrão.
#
# O desvio padrão é uma medida de dispersão que mostra o quanto os valores em um
# conjunto de dados variam em relação à média. Em poucas palavras, desvio significa apenas o quão longe do normal, no melhor sentido da palavra o desvio padrão é uma medida de quão espalhado os número estão. Quando aplicado a séries temporais sobre vendas, o MSD pode fornecer uma medida da volatilidade do preço final de vendas no dia que ocorreu.
#
# Para calcular o MSD, você primeiramente calcula a média móvel dos pontos de dados. Em
# seguida, para cada ponto na janela, você subtrai a média móvel e eleva o resultado ao quadrado. Depois, você soma todos esses valores quadrados, calcula a média deles e, finalmente, tira a raiz quadrada do resultado.
#
# Essencialmente, o MSD fornece uma medida da volatilidade que se move junto com o
# tempo, da mesma forma que uma média móvel acompanha a **tendência central dos dados.** É
# frequentemente usado em análises financeiras e técnicas para medir a volatilidade dos preços das ações ao longo do tempo.

# %%
df_dropna.head()
# Out:
#             discount  unitprice  quantity  storeid       date  sales_amount  sales_discount  final_sales_price  total_sales_per_day  total_sales_per_hour  avg_sales_per_day  avg_sales_per_hour
# date
# 2018-03-01       0.1      156.8         1        1 2018-03-01         156.8           15.68             141.12              5295.78               5295.78         182.613103          182.613103
# 2018-03-02       0.1      117.6         1        2 2018-03-02         117.6           11.76             105.84              6930.00               6930.00         198.000000          198.000000
# 2018-03-03       0.1      201.6         1        1 2018-03-03         201.6           20.16             181.44              8260.56               8260.56         211.809231          211.809231
# 2018-03-04       0.1      233.8         1        3 2018-03-04         233.8           23.38             210.42              6599.88               6599.88         188.568000          188.568000
# ...

# %%
# Function SMA and MSD
def sma_and_msd(df):

    # Copy of dataframe
    df_copy = df.copy()

    # Cria a variável com o retorno (mudança percentual do total sales per day de on dia for other )
    # This will our variable target
    df_copy["perc_return"] = df_copy["total_sales_per_day"].pct_change(1) * 100

    # Shift das colunas op sales toys
    df_copy["sa"]  = df_copy["sales_amount"].shift(1) 
    df_copy["sd"]  = df_copy["sales_discount"].shift(1)
    df_copy["sd"]  = df_copy["final_sales_price"].shift(1)
    df_copy["tsd"] = df_copy["total_sales_per_day"].shift(1)
    df_copy["tsh"] = df_copy["total_sales_per_hour"].shift(1)
    df_copy["avsd"]= df_copy["avg_sales_per_day"].shift(1)
    df_copy["avsh"]= df_copy["avg_sales_per_hour"].shift(1)

    # Calculando os OKR's

    # Simple Moving Average (SMA)
    df_copy["SMA_3"] = df_copy[["total_sales_per_day"]].rolling(3).mean().shift(1)
    df_copy["SMA_5"] = df_copy[["total_sales_per_day"]].rolling(5).mean().shift(1)

    # Moving Standard Deviation (MSD) - Volatilidade
    df_copy["MSD_3"] = df_copy["perc_return"].rolling(3).std().shift(1)
    df_copy["MSD_5"] = df_copy["perc_return"].rolling(5).std().shift(1)

    return df_copy.dropna()

# %% [markdown]
# Vamos percorrer os termos-chave desta function
#
# - Primeiro, cria uma cópia do dataframe para não modificar o dataframe original.
#
# - Em seguida, cria uma nova coluna 'retorno', que representa a mudança percentual total sales per day em relação ao dia anterior. Vemos isso como um retorno, ou seja, se aumentar de um dia para outro resulta em ganho e se diminuir resulta em perda.
#
# - Estamos criando a variable return com base em uma rule, cada empresa pode ter regras diferentes para cálculo de retorno, ou seja, pode haver um fator adicional que a empresa multiplica por 1.5 ou divide por 1.2 e assim por diante. Assim como, é preciso entender as regras utilizadas pela empresa para calcular o retorno, neste exemplo nós usamos a variação percentual de um dia para outro.
#
#
# - As colunas **quantity ,sales_amount, sales_discount, final_sales_price, total_sales_per_day, total_sales_per_day, total_sales_per_hour, avg_sales_per_day e avg_sales_per_hour** são então deslocadas para baixo (shifted) em uma unidade, criando novas variables. Isso significa que a linha 'i' dessas novas variables contém os valores da linha 'i-1' das variables originais.
#
# - A função também cria médias móveis simples (Simple Moving Average - SMA) para o total sales per day com janelas de 3 e 5 dias, deslocadas por uma unidade.
#
# - A volatilidade, representada como o desvio padrão das mudanças percentuais do **total sales per day**, é calculada para as janelas de 3 e 5 dias, também deslocadas por uma unidade. Esse índice é conhecido como Moving Standard Deviation (MSD).
#
#
# - Em resumo, this function cria várias novas variables técnicas comumente usadas na análise de ativos financeiros e assim como em qualquer disciplina de time series, todas deslocadas por uma unidade, para evitar o uso de informações futuras (ou seja, vazamento de dados) no modelo de Machine Learning.

# %%
# Function call
df_new = sma_and_msd(df_dropna)

# Function calls to calculate the differences
functions_aux.summary_quick_in_between_datasets(df_new,df_dropna)
# Out:
# First dataset, get the number of rows and columns: (666, 23)
# Get the number of elements: 15318
#
# First dataset, get the number of rows and columns: (672, 12)
# Get the number of elements: 8064
# ----------------------------------------------------------------------
# Difference between datasets in rows: 6 and columns: 11

# %% [markdown]
# ### 2.2.2. Atributos Date Time
#
# Podemos usar o registro de data e hora e gerar um recurso chamado *is_holiday*, que informa se um dia é feriado ou não. Além disso podemos transformar a data e hora em diversas outras variáveis de data.

# %%
# Function call 
df_ts = ts.create_dt_attributes(df_new)
df_ts.head()
# Out:
#             discount  unitprice  quantity  storeid       date  sales_amount  sales_discount  final_sales_price  total_sales_per_day  total_sales_per_hour  avg_sales_per_day  avg_sales_per_hour  perc_return     sa      sd      tsd      tsh        avsd        avsh    SMA_3     SMA_5      MSD_3      MSD_5  month  day_of_month  day_of_year  week_of_year  day_of_week  year  is_weekend  start_of_month  end_of_month  is_holiday
# date
# 2018-03-07       0.1      214.2         1        2 2018-03-07         214.2           21.42             192.78              8321.04               8321.04         198.120000          198.120000    -8.009472  134.4  120.96  9045.54  9045.54  205.580455  205.580455  7775.04  7703.136  21.475874  19.282571      3             7           66            10            3  2018           0               0             0           0
# ...

# %% [markdown]
# ### 2.2.3. Handling Text and Categorical Attributes

# %% [markdown]
# Agora vamos pré-processar alguns recursos de entrada categórica, como a loja, produto, dia da semana e mês.

# %%
# Converte variáveis categóricas em variáveis dummy aplicando One-Hot Encoding

#df_dummies = pd.get_dummies(df_ts, columns = ['storeid','day_of_week', 'month'],drop_first=True) #https://stackoverflow.com/questions/63661560/drop-first-true-during-dummy-variable-creation-in-pandas
df_dummies = pd.get_dummies(df_ts, columns = ['storeid','day_of_week', 'month','year'])

# check difference
functions_aux.summary_quick_in_between_datasets(df, df_dummies)

# Checking for duplicate records.
print(f'\nValues duplicated: {df_dummies.duplicated().sum()}')
# Out:
# First dataset, get the number of rows and columns: (32753, 18)
# Get the number of elements: 589554
#
# First dataset, get the number of rows and columns: (666, 58)
# Get the number of elements: 38628
# ----------------------------------------------------------------------
# Difference between datasets in rows: 32087 and columns: 40
#
# Values duplicated: 0

# %% [markdown]
# ### 2.3. Time Series Decomposition and Stationarity Test

# %% [markdown]
# Em primeira análise, vamos decompor nossa série temporal. Mas, antes disso, discutiremos dois conceitos elementares sobre decomposição de séries temporais, temos:
#
# A **decomposição aditiva** em séries temporais  é um método para desagregar uma série
# temporal em componentes diferentes, geralmente tendência, sazonalidade e ruído. A tendência  representa a variação geral ao longo do tempo, a sazonalidade representa variações regulares ao  longo do tempo (como variações  mensais ou anuais) e o ruído representa variações aleatórias. A  decomposição é chamada "aditiva" porque as componentes são adicionadas juntas para formar  a série temporal original.
#
# A **decomposição  multiplicativa**  em  séries  temporais também é  um  método  para desagregar  uma  série  temporal  em  componentes  diferentes,  geralmente  tendência, sazonalidade e ruído.  A decomposição é chamada "multiplicativa" porque as componentes são  multiplicadas juntas para formar a série temporal original.
#
#
# Dependendo da natureza da tendência e da sazonalidade, uma série temporal pode ser modelada como aditiva ou multiplicativa, em que cada observação na série pode ser expressa como uma soma ou um produto dos componentes:
#
# - **Séries Temporais Aditivas:**
#
#         Valor = Nível Base + Tendência + Sazonalidade + Erro
#
#
# - **Séries Temporais Multiplicativas:**
#
#         Valor = Nível Base x Tendência x Sazonalidade x Erro
#
#
# - Podemos usar os modelos estatísticos para realizar uma decomposição dessa série cronológica.
#
# - A decomposição de séries temporais é uma tarefa estatística que desconstrói uma série temporal em vários componentes, cada um representando uma das categorias de padrões.
#
# - Os modelos de estatísticos, poderemos ver a tendência, os componentes sazonais e residuais de nossos dados.
#
# Assim sendo, você pode fazer uma decomposição clássica de uma série temporal, considerando a série como uma combinação aditiva ou multiplicativa do nível base, tendência, índice sazonal e residual.
#
# ### 2.3.1. Por Que Fazemos a Decomposição da Série?
#
# **A decomposição da série permitirá identificar quais componentes estão atuando naquele conjunto em particular, além de possibilitar obter índices e/ou equações para realizar previsões para períodos futuros da série.**
#
# Além disso, a decomposição da Série Temporal em seus componentes no qual as séries possuem dois tipos principais de componentes:
#
# - Estruturais (ciclo, sazonalidade e tendência)
# - Não Estruturais (qualquer tipo de padrão irregular não associado aos componentes estruturais)
#
#
# A questão crucial do modelo clássico é decidir como será a equação que relaciona os componentes com a variável. Há duas opções: o modelo aditivo ou o modelo multiplicativo.
#
# No modelo aditivo o valor da série (Y) será o resultado da soma dos valores dos
# componentes (que apresentam a mesma unidade da variável):
#
#     Y = T + C + I (se os dados forem registrados anualmente)
#
# Nas previsões não temos como incluir a componente irregular no modelo, pois ela é resultado de fatos fortuitos, teoricamente imprevisíveis. Todos os componentes têm a mesma unidade da série: se esta for em milhões de reais todas também terão tal unidade.
#
# Modelos de Decomposição consistem em, como o próprio nome diz, decompor o modelo que descreve o comportamento da série temporal através de seus componentes:
#
# - Valor da série temporal = padrão temporal + erro
# - Valor da série temporal = f (Tendência, Sazonalidade, Ciclo, Ruído Aleatório) ou:
#
#         Yt = f (Tt, St, Ct, It)
#
# **Onde:**
#
# - Yt é o valor da série temporal
# - Tt é o componente Tendência no período t
# - St é o componente de Sazonalidade no período t
# - Ct é o componente Ciclo no período t
# - It é o componente irregular, ou seja, de erro, Ruído Aleatório, ou padrão subjacente no período t
#
# Pode ser usado também o modelo multiplicativo, no qual o produto das componentes resultará na variável da série:
#
#
#     Y = T x C x S x I (se os dados forem registrados anualmente)
#
# Novamente, não incluímos a componente irregular. Há, porém, uma diferença crucial: apenas a tendência tem a mesma unidade da variável. As demais componentes têm valores que modificam a tendência: assumem valores em torno de 1 (se maiores do que 1 aumentam a tendência, se menores diminuem a tendência, se exatamente iguais a 1 não causam efeito).
#
# > A tendência descreve o comportamento da variável retratada na série temporal no longo prazo. Há três objetivos básicos na sua identificação: avaliar o seu comportamento para utilizá-lo em previsões, removê-la da série para facilitar a visualização das outras componentes, ou ainda identificar o nível da série (o valor ou faixa típica de valores que a variável pode assumir, se não for observado comportamento crescente ou decrescente no longo prazo). A obtenção da tendência pode ser feita de três formas: através de um modelo de regressão
# (como o modelo linear - reta), através de médias móveis (Moving Average), ou através de
# ajuste exponencial (que não deixa de ser uma média móvel).
#
#
# **Em adição, classificamos uma série como aditiva sempre que houver um crescimento na tendência (em relação ao período anterior) ou se a amplitude do componente sazonal permanecer aproximadamente a mesma ao longo do tempo. Por outro lado, classificamos uma série como multiplicativa sempre que o crescimento da tendência ou a magnitude do componente sazonal aumentar ou diminuir em alguma multiplicidade de período para período ao longo do tempo.**
#
#
# > O modelo Aditivo é mais indicado quando a tendência sazonal é da mesma magnitude em todo o conjunto de dados, enquanto o Modelo Multiplicativo é preferido quando a magnitude da sazonalidade muda à medida que o tempo aumenta.

# %% [markdown]
# A função seasonal_decompose do pacote Statsmodels em Python implementa isso de uma maneira convenientemente, a seguir para nossa série temporal da demanda de vendas por hora:

# %%
''' 
Select the registro a partir date choose
ts1= df_dummies[(df_dummies['date'] >= '2018-03-16') & (df_dummies['date'] <= '2018-03-31')]
ts2= df_dummies[(df_dummies['date'] >= '2019-02-13') & (df_dummies['date'] <= '2019-02-28')]

Concat
ts_irregular = pd.concat([ts1,ts2], axis=0)
ts_irregular
'''

# delete all rows with date estabelecidade
ts_regular = df_dummies[(df_dummies['date'] <='2019-02-28')].index
df_dummies.drop(ts_regular, inplace=True)

# %%
# Additive Decomposition
addi_decomposition = sm.tsa.seasonal_decompose(df_dummies.total_sales_per_day, model = 'aditive',extrapolate_trend='freq' ,period=84)

# Multiplicative Decomposition
mult_decomposition  = sm.tsa.seasonal_decompose(df_dummies.total_sales_per_day, model = 'multiplicative',extrapolate_trend = 'freq', period=84)

# Plot
plt.rcParams.update({'figure.figsize': (16,10)})
addi_decomposition.plot().suptitle('Additive Decomposition', fontsize = 12)
mult_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize = 12)
plt.show()

# Viewing the data statistics
pd.options.display.float_format = "{:,.2f}".format
df_dummies.total_sales_per_day.describe()
# Out:
# count      325.00
# mean     9,842.21
# std      4,017.42
# min      1,566.18
# 25%      6,972.84
# 50%      9,056.88
# 75%     12,567.24
# max     21,268.74
# Name: total_sales_per_day, dtype: float64

# %% [markdown]
# ### 2.3.2. Interpretando a Decomposição da Time Series:
#
# **Série Temporal Original:** o primeito subplot mostra a série temporal original. É importante observar se a série apresenta tendências, padrões sazonais ou flutuações aleatórias, que podem ajudar a entender melhor seu comportamento e identificar possíveis fatores que influencia a série.
#
# **Tendência:** o segundo subplot mostra a tendência estimada da série temporal. A tendência indica a direção geral da série, se ela está aumentando, diminuindo ou se mantendo constante ao longo do tempo. A presença de tendêndia  é importante para análise, pois pode influenciar na previsão de valores futuros da série.
#
# **Sazonalidade:** o terceiro subplot mostra o componente sazonal estimada da série temporal. A sazonalidade indica padrões que se repetem em intervalos regulares de tempo, como diariamente, semanalmente ou anualmente. Identificar esses padrões é importante para análise, pois eles podem ser úteis para prever valores futuros da série, especialmente em séries com forte componente sazonal.
#
# **Resíduos:** o quatro subplot mostra os resíduos estimados da série temporal. Os resíduos são as flutuaçções aletórias que não podem ser explicadas pela tendência ou pela sazonalidade. Observar a distribuição dos resíduos é importante para avaliar a qualidade do modelo de decompisão e identificar possíveis problemas na análise, como erros de modelagem, outliers ou anomalias.
#
# De acordo com os conceitos discutido anteriormente, a figura a seguir simplificar os detalhes das explicações.
#
# ![image.png](attachment:44162c11-df3b-43c0-aa78-c3b76531bce9.png)
#
#
# **Padrões Semanais:** A principal vantagem de analisar dados semanais é a capacidade de identificar padrões que ocorrem ao longo da semana. Por exemplo, se você está analisando dados de vendas de uma loja, pode descobrir que as vendas aumentam nos finais de semana e diminuem no meio da semana.
#
# **Sazonalidade:** A sazonalidade é uma característica importante na análise de séries temporais e pode ser semanal, mensal, trimestral, anual, etc. Ao analisar dados semanais, você pode identificar a sazonalidade semanal. Por exemplo, um restaurante pode ter mais clientes nos finais de semana do que nos dias de semana.
#
# **Ruído:** A análise de dados semanais pode ajudar a reduzir o ruído presente em dados diários. Se você tem dados muito voláteis em uma base diária, a agregação para uma base semanal pode suavizar essa volatilidade.
#
# Quanto à análise dos dias da semana, é uma técnica semelhante, mas com um foco mais específico. Aqui, você está interessado em padrões que ocorrem em dias específicos da semana. Por exemplo, você pode querer saber se as vendas são consistentemente maiores às sextas-feiras ou se as visitas a um site são mais baixas às segundas-feiras.
#
# ---
#
# No gráfico da decomposição podemos ver os componentes da série temporal:
#
# 1. A primeira linha do gráfico mostra os dados observados. A série de demanda de vendas de briquendos por dia entre **março de 2018 e fevereiro de 2020 apresentou um comportamento aparentemente estancionário.** Seus valores convergiram para uma **média próximo de 9,842 reais de vendas por dia** e a variabilidade não se modificou substancialmente no período, com valores entre 1,566.18 e 21,268.74 reais.
#
# 2. A segunda linha mostra a tendência da série, que apresenta uma tendência  relativamente uniforme, ou seja, a demanda de vendas por dia apresenta um crescimento uniformemente em intervalos tempo consecutivos, isto significa, que as vendas flutuam ao longo do tempo próximo de uma distribuição uniforme.
#
# 3. A terceira linha mostra a sazonalidade. Claramente temos períodos regulares de aumento e queda, momentos em que temos valores maiores ou menores do total de vendas de brinquedos por dia.
#
# 4. A quarta linha é o componete irregular ou resíduo.Se você olhar atentamente para o resíduo da decomposição aditiva e multiplicativa, os comportamentos parece bastante aleatória, o que é bom.
#
# Em síntese, esta série é provavelmente estacionária, assim como, se você possui uma tendência e uma sazonalidade claras em suas séries temporais, modele esses componentes, remova-os das observações e treine seu modelo. Da mesma forma, se ajustarmos um modelo estacionário aos dados, assumimos que nossos dados são a realização de um processo estacionário. Portanto, nosso primeiro passo na análise deve ser verificar se há alguma evidência de uma tendência ou efeitos sazonais e, se houver, removê-los.
#
# Além do mais, antes de iniciar qualquer modelagem preditiva de uma série temporal, é necessário verificar se essas propriedades estatísticas são constantes ao longo da série temporal:
#
# - **Estacionariedade**: a série temporal **deve** ser estacionária, ou seja, suas características estatísticas, como média e variância, não mudam ao longo do tempo.
#
#
# - **Não-autocorrelação**: as observações da série temporal não devem ser fortemente correlacionadas com observações anteriores.
#
#
# - **Normalidade**: é frequentemente pressuposto que as observações da série temporal são distribuídas normalmente (seguem uma distribuição normal).

# %% [markdown]
# ### 2.3.2.1. Taxa percentual de crescimento diário

# %%
#perc_return_neg = df_dummies.query('perc_return > 0.0'), df_dummies.query('perc_return < 0.0')

# %% [markdown]
# ### 2.3.3. Stationarity Test

# %% [markdown]
# Segundo (Aileen, 2021) defende que uma série temporal estacionária é aquela cuja medição de sua série temporal reflete um sistema em um estado estável. Às vezes, é difícil
# afirmar exatamente o que uma série temporal estacionária significa e pode ser mais fácil considerá-la como algo que não fica parado em vez de dizer
# que é algo estacionário.
#
#
# **A estacionariedade é um importante conceito na modelagem de séries temporais e é caracterizada por uma variável que se comporta de forma aleatória ao longo do tempo ao redor de uma média constante.** Por exemplo, caso o comportamento da série seja não
# estacionário, ou seja, mude com o tempo, seria muito difícil estabelecermos um modelo de previsão para seus valores futuros baseado no seu comportamento passado. Analogamente, seria muito difícil estabelecermos uma relação de determinação para uma variável dependente em função de variáveis independentes caso essa
# relação apresente importantes quebras estruturais com o tempo.
#
# Principalmente, séries temporais que possuem tendência e/ou sazonalidade não são estacionárias e é necessário o uso de técnicas adequadas a tal situação. Em termos mais formais, se  uma  série  temporal  não  mostrar  um  padrão  crescente  ou  decrescente,  a  série  será estacionária, assim como, uma série estacionária é o que em matemática costuma se chamar série convergente, ou seja, aquela que flutua em torno de uma mesma média ao longo do tempo.
#
#
# De modo menos formal, uma série temporal é estacionária quando suas características estatísticas (média, variância, auto correlação, etc…) são constantes ao longo do tempo. É uma série que se desenvolve aleatoriamente no tempo, em torno de uma média constante, refletindo alguma forma de equilíbrio estatístico estável (ou seja, as leis de probabilidade que atuam no processo não mudam com o tempo). Para muitas séries temporais, essa suposição é razoável (por exemplo, para reações químicas a suposição é boa, já que as leis da química não mudam de uma hora para outra), mas para muitas outras não é (por exemplo, os mercados financeiros são reconhecidamente não
# estacionários, uma vez que os padrões desaparecem assim que os investidores os identificam e começam a explorá-los).
#
# Muitas séries são inerentemente não-estacionárias e exibem tendências, ciclos, padrões sazonais e outros comportamentos não-estacionários. Métodos de previsão (forecasting) usam transformações matemáticas para “estacionarizar” uma série e fazer previsões nesta série mais “bem-comportada”, para depois inverter as transformações e obter as previsões para a série original. Transformações comuns são: tomar diferenças sucessivamente, deflacionar, aplicar log (p/estabilizar variâncias), fazer ajustes sazonais, de-trending (ajustar um “trend” e subtraí-lo), etc...
#
#
# Observa-se que, (Alexandre.G, 2017) destacar que em um processo estacionário, o valor de Y tende a convergir para uma média constante, sua variabilidade não muda com o tempo e a
# relação entre, por exemplo, o valor presente Y t e seu valor defasado
# Yt – 1 será a mesma em todos os pontos de t. Em processos não
# estacionários, o valor esperado de Yt é diferente em cada período, sua
# variância não é constante no tempo e/ou as relações entre os valores
# presentes e defasados se modificam com o tempo.
#
# ![image.png](attachment:dd4c5c54-d867-421d-8123-8d5b2a5229c1.png)
#
# > Source: (Alexandre.G, 2017)
#
# Em modelos de previsão, (Alexandre.G, 2017) afirma que a estacionariedade é importante, primeiro,
# porque supõe que o relacionamento entre Y t e seus valores defasados
# Y t – s seja o mesmo em todos os períodos t. Segundo, porque sinaliza
# a convergência da série para uma média histórica segundo uma
# distribuição de probabilidade previsível. Em modelos de RLM, a não
# estacionariedade pode implicar na instabilidade dos coeficientes
# angulares, assim como pode se refletir nos erros do modelo que, além
# de poderem não apresentar uma média constante, tenderiam a
# apresentar uma variabilidade crescente no tempo. Nesse caso, os
# estimadores de MQO deixariam de ser consistentes
#
# > Source: (Alexandre.G , 2017)
#
# Em outras palavras, assumimos que a série temporal é estacionária (pelo menos, em
# um sentido amplo). Por definição, a média, a variância e as autocorrelações de uma série temporal estacionária (ou seja, correlações entre os valores na série temporal separados por um determinado intervalo) não mudam ao longo do tempo. É algo restritivo; por exemplo, isso exclui séries temporais com tendências ou padrões cíclicos. As Redes neurais recorrentes (RNNs) são mais tolerantes, pois conseguem aprender tendências e padrões cíclicos. (Aurélien.G, 2021).
#
# Termo-chave
#
# - A estacionariedade refere-se à propriedade de uma série temporal em que as propriedades estatísticas (como média, variância e autocorrelação) são constantes ao longo do tempo.

# %% [markdown]
# ### 2.3.3.1. Verificando a Estacionariedade
#
# Podemos verificar a estacionariedade de uma série temporal da seguinte forma:
#
# - **Plot das Rolling Statistics (Estatísticas Móveis)**: Podemos criar um plot da média móvel e variância móvel (ou desvio padrão, que é a raiz quadrada da variância) e ver se variam com o tempo. A média / variância móvel é, para qualquer instante 't', a média / variância do último ano, ou seja, os últimos 12 meses.
#
#
# - **Autocorrelação com Gráficos ACF e PACF**: Se a série temporal for estacionária, os gráficos ACF / PACF (gráficos de autocorrelação da série) mostrarão um padrão específico o qual discutiremos mais adiante.
#
# - **Teste Dickey-Fuller**: Este é um dos testes estatísticos para verificar a estacionariedade. Aqui, a hipótese nula é que a série temporal não é estacionária. Os resultados do teste incluem uma estatística de teste e alguns valores críticos para os níveis de confiança das diferenças. Se a 'Estatística de teste' for menor que o 'valor crítico', podemos rejeitar a hipótese nula e dizer que a série é estacionária.
#
# Dessa forma, usaremos os 3 métodos para checar se a nossa série é estacionária ou não.

# %% [markdown]
# ### 2.3.4. Rolling Average

# %% [markdown]
# Em Estatística, uma média móvel (moving average ou rolling average ou running average) é um  cálculo para analisar pontos de dados criando uma série de médias de diferentes subconjuntos  do conjunto de dados completo. É também chamado de moving mean or rolling mean. Em outras palavras, **é média dos últimos n valores em um conjunto de dados, aplicada linha por linha, para que você obtenha uma série de médias.**
#
# - As variações incluem formas: simples, cumulativas ou ponderadas.
#
# A média móvel é um tipo de Rolling Statistic, que inclui desvio padrão, valores máximo e  mínimo e diferença.
#
# Vejamos um exemplo:
#
# ![image.png](attachment:c9e35225-2dce-45a2-bea2-08c0f604fe41.png)
#
# > Source: (Ian.L, 2009)
#
# ### 2.3.4.1. Por que usar uma média móvel?
#
# Uma média móvel pode ajudá-lo a encontrar tendências que, de outra forma, seriam difíceis de detectar. Usando os dados acima, você obtém um gráfico parecido com este:
#
# Rolling Average é uma janela deslizante do conjunto de dados, que calcula séries de médias, conforme a figura ilustra você consegue detectar algum padrão de tendência nesse gráfico?
#
# ![image.png](attachment:acf9aeaf-4298-46bb-8a84-c438f19a16f8.png)
#
# > Source: (Ian.L, 2009)
#
# No entanto, usar uma média móvel, porém, e você começará a ver um padrão emergir, com picos acontecendo cada vez com mais frequência:
#
# ![image.png](attachment:79d1b504-6cba-4a9d-b85c-9ad1c17c3327.png)
#
# Conforme a figura acima ilustra, agora, temos um padrão devido a Rolling Average vejamos que picos estão se tornando cada vez mais comuns ao longo do tempo. É por isso que as médias móveis são tão úteis: aplique-as no momento certo e você poderá ter uma ideia das tendências emergentes, mesmo que essas tendências ocorram devido a saltos repentinos em seus dados.
#
# As estatísticas são usadas para resumidos os dados. Dessa forma, se não empregamos Rolling Average estaríamos coletando informações que não representa padrão que os dados possuir. Além disso, Rolling Average nós fornece um séries de informações tais como: séries de média, desvio-padrão, valor min e max, diferença e assim por diante.
#
# Uma média móvel é comumente usada com dados de séries temporais para suavizar
# flutuações de curto prazo e destacar tendências ou ciclos de longo prazo. O limiar entre  curto e longo prazo depende da aplicação. Por exemplo, é frequentemente usado na análise técnica de dados financeiros, como preços  de ações, retornos ou volumes de negociação. Também é usado em economia para examinar  o produto interno bruto, emprego ou outras séries temporais macroeconômicas. **Matematicamente, uma média móvel é um tipo de convolução e, portanto, pode ser vista  como um exemplo de filtro usado no processamento de sinais (o que é usado Deep Learning).**

# %% [markdown]
# ### 2.3.5. O Que São Lags (Defasagens ou Atrasos)?
# Uma maneira de analisar os dados de séries temporais é plotar cada observação contra outra observação que ocorreu algum tempo antes. Por exemplo, você pode plotar yt contra yt-1. Nesse caso, yt-1 é o atraso da série, o lag, isso é chamado graph de atraso (lag plot), porque você está plotando as séries temporais contra defasagens.
#
# As correlações associadas aos gráficos de atraso formam o que é chamado de "função de autocorrelação". **A autocorrelação é quase a mesma que a correlação de Pearson (que usamos em modelos de Regressão).** No entanto, a autocorrelação é a correlação de uma série temporal com uma cópia atrasada (lag, atraso ou defasagem) de si mesma.
#
# **A função de autocorrelação (ACF) é o principal método na análise de séries temporais para quantificar o nível de correlação entre uma série e seus atrasos. Esse método é bastante semelhante (matematicamente e logicamente) ao coeficiente de correlação de Pearson.**
#
# O uso das defasagens (lags) da série para prever o valor futuro da série é benéfico sempre que a série apresenta padrões repetidos estáveis ao longo do tempo. No entanto, a principal armadilha desse método é que ele falhará sempre que as alterações nas séries derivarem de fatores exógenos. Nesses casos, o uso apenas de atrasos (lags) passados pode levar a resultados enganosos, pois os  atrasos não necessariamente conduzem às mudanças na série. **O objetivo da análise de causalidade, no contexto da análise de séries temporais, é identificar se existe uma relação de causalidade entre a série que desejamos prever e outros fatores exógenos em potencial.** O uso desses fatores externos como direcionadores do modelo de previsão (sempre que existir) poderia fornecer previsões precisas e robustas (em vez de usar apenas a observação  anterior da série). **Uma ponto importante que vale apena ressaltar que não existe uma análise perfeita neste cenário.**

# %% [markdown]
# ### 2.3.6. Função de Autocorrelação
#
# Os modelos estatísticos mais conhecidos e utilizados, como a Regressão Linear e o Regressão Logística, são adequados na modelagem de variáveis em que as observações são independentes. **Em uma série temporal, não há como desconsiderar a estrutura de dependência das observações.**
#
# Por exemplo, a quantidade vendida de sorvete em janeiro pode estar relacionada à quantidade vendida em dezembro, que por sua vez pode estar relacionada com a de novembro e assim por diante. Dessa forma, a utilização desses modelos pode gerar resultados enviesados e que não refletem a realidade.
#
# A autocorrelação é definida como uma observação num determinado instante está relacionada às observações passadas. Em outros termos, a Função de Autocorrelação (ACF – Autocorrelation Function) descreve os padrões de relacionamento entre valores presentes e defasados de Y, permitindo identificar a presença de estacionariedade em um processo estocástico. A partir das correlações entre valores observados em um período base t e seus valores defasados t − k, é possível verificar em que medida os valores de um período base influenciam ou são influenciados por valores defasados da série.
#
# As observações podem estar autocorrelacionadas em diversas ordens. A autocorrelação de primeira ordem caracteriza séries onde uma observação está correlacionada com a observação imediatamente anterior (janeiro e dezembro, por exemplo). A autocorrelação de segunda ordem caracteriza séries temporais onde uma observação está correlacionada com as observações a 2 unidades de tempo no passado (janeiro e novembro, por exemplo).
#
# A identificação da autocorrelação é feita através da ACF, mostrada adiante nos gráficos. Além disso, testes como o de Durbin Watson auxiliam na identificação da autocorrelação de primeira ordem.
#
# **A autocorrelação é uma ferramenta matemática para encontrar padrões de repetição, como a presença de um sinal periódico obscurecidos pelo ruído. Um diagrama de autocorrelações apresenta os valores de autocorrelação de uma amostra versus o intervalo de tempo em que foi calculado. Autocorrelações devem ser próximas de zero para aleatoriedade. A ocorrência de não estacionariedade é denotada pela lenta queda da ACF nos primeiros lags da série. Isto significa que a série deve ser diferenciada**
#
#
# Antes de iniciar qualquer modelagem preditiva é necessário verificar se essas propriedades estatísticas são constantes na série temporal:
#
# - Média constante
# - Variância constante
# - Autocorrelacionada
#
# De modo menos formal, a autocorrelação dá uma ideia de como os pontos de dados em diferentes pontos no tempo estão linearmente relacionados entre si em função de sua diferença de tempo. Em outra palavras, o objetivo da autocorrelação é que possamos determinar quais períodos da série estão mais correlacionados com a série. No entanto, a autocorrelação sempre informará se **período anterior afetará ou não o próximo período da série.**
#
#
# Em termos matemáticos, segundo (Aileen.N, 2021) destacar que existem alguns fatos importantes sobre a função ACF:
#
# - A ACF de uma função periódica tem a mesma periodicidade do processo original.
#
# - A autocorrelação da soma das funções periódicas é a soma das autocorrelações de cada função separada.
#
# - Todas as séries temporais têm uma autocorrelação de 1 no lag 0.
#
# - A autocorrelação de uma amostra de ruído branco terá um valor de aproximadamente 0 em todos os lags diferentes de 0.
#
# - A ACF é simétrica em relação aos lags negativos e positivos, assim apenas os lags positivos precisam ser considerados explicitamente.
#
# - A ACF de dados estacionários normalmente cai para o valor zero bem rápido. Já para dados não estacionários, o valor no lag 1 é positivo e é grande.

# %% [markdown]
# ### 2.3.7. Função de Autocorrelação Parcial

# %% [markdown]
# Segundo (Aileen.N, 2021) refina que A Função de Autocorrelação Parcial (PACF) indica que a autocorrelação parcial é mais substancial na série somada do que em qualquer uma das séries originais. Ou seja, a correlação entre os pontos separados por um determinado lag, quando se calcula os valores dos pontos entre eles, é mais informativa na série somada do que na série original. Isso está relacionado aos dois períodos diferentes da série, resultando com que qualquer ponto seja menos determinado pelos valores dos pontos vizinhos
# uma vez que a localização dentro do ciclo dos dois períodos se torna menos
# fixa, pois as oscilações continuam em frequências diferentes.

# %% [markdown]
# ### 2.3.8. ACF e PACF
#
# Seguindo análise dos conceitos citados anteriormente, podemos criar os gráficos da (ACF) e (PACF).

# %%
# Plots
plt.rcParams.update({'figure.figsize': (16,10)})
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

# Plot do gráfico ACF
plot_acf(df_dummies.total_sales_per_day, ax=axs[0], lags=56) # sempre vai verificar 14 atrasos da série para cálcula
axs[0]

# Plot do gráfico PACF
plot_pacf(df_dummies.total_sales_per_day,ax=axs[1], lags=56, method="ywm")
axs[1]
plt.show()

# %% [markdown]
# Interpretação dos Gráficos:
#
# No gráfico, o eixo vertical indica a autocorrelação e o horizontal a defasagem.
#
# A área sombreada em azul indica onde é significativamente diferente de zero. Como é possível ver na imagem, temos poucos valores ACF (barras verticais) acima do limite da área sombreada em azul no início da série próximo do lag 15. Nesses casos, a autocorrelação é diferente de zero, indicando que a série não é aleatória conforme o esperado.
#
# Além do mais, grande parte das barras verticais estão dentro do limite da área sombreada em azul. Ou seja, **a autocorrelação entre a série com alguns de seus lags é igual a zero, indicando que não há correlação.**
#
# - Em termos simples: a área sombreada em azul aponta a significância (idealmente os pontos de dados devem está na área sobreada azul, isso indica que não autocorrelação). Se ultrapassada é porque tem correlação.**
#
# Acrescenta-se que, cada barra no gráfico ACF representa o nível de correlação entre a série e seus atrasos em ordem cronológica. **A área sombreada em azul indica se o nível de correlação entre a série e cada atraso é significativo ou não.**
#
# Ainda mais, testando a hipótese nula de que a correlação do atraso com a série é igual a zero, podemos rejeitá-la sempre que o **nível de correlação estiver acima ou abaixo da área sombreada em azul com um nível de significância de 5%.**
#
# Portanto, caso contrário, sempre que a correlação estiver dentro da área sombreada em azul,  deixamos de **rejeitar a hipótese nula e, portanto, podemos ignorar esses atrasos (ou assumir que não há correlação significativa entre eles e a série).**
#
# O PACF é apenas uma visualização parcial do ACF.
#
# Como você pode ver no gráfico ACF da série total de vendas por dia de brinquedos, a série tem uma forte correlação positiva com os atrasos
# sazonais (que decaem ao longo do tempo) juntamente com uma correlação negativa com os atrasos (por exemplo, pŕoximos dos atrasos 25 a 56).

# %% [markdown]
# **Indicadores**
#
# - Se a série temporal for estacionária, os gráficos do ACF / PACF mostrarão uma "queda rápida na correlação" após um pequeno atraso entre os pontos.No entanto, é o caso em nossos gráficos. A queda rápida (redução do tamanho das barras) indica que essa série provalvemente é estacionária.
#
#
# - Os dados da nossa série são estacionários, pois um número alto de observações estão na área sobreada azul, ou seja, os dados não estão correlacionados com valores futuros.
#
#
# - Intervalos de confiança são desenhados na área azul clara. Por padrão, isso é definido como um intervalo de confiança de 95%, sugerindo que os valores de correlação fora desta área provavelmente são uma correlação e não um acaso estatístico.

# %% [markdown]
# ### 2.3.9. Teste Dickey-Fuller Aumentado

# %% [markdown]
# O teste de estacionriedade usual, proposto Dickey-Fuller, em 1979, conhecido **Teste de Dickey-Fuller aumentado ou Teste ADF (do acrônimo em inglês Augmented Dickey-Fuller)** é um teste de raiz unitária em séries temporais. Ele é uma versão aumentada do Teste de Dickey-Fuller, é aplicado a modelos mais complicados de séries temporais.
#
#
# A estatística ADF do  teste assume uma hipótese nula de raiz unitária na série temporal. Dependendo dos resultados do teste, essa hipótese nula pode ser rejeitada no nível de significância especificado, o que significa que a presença de um teste de raiz unitária pode ser rejeitada no nível de significância fornecido.
#
# O nome do teste faz referência aos estatísticos D. A. Dickey e W. A. Fuller.
#
#
# A intuição por trás do teste é que, se a série for integrada, o nível de atraso da série y (t-1) não fornecerá informações relevantes na previsão da mudança em y (t).
#
#
# | Hipótese| Descrição do teste|
# |---|:-------------|
# | **H0 (Hipótese Nula):** |A série temporal não é estacionária.|
# | **H1 (Hipótese Alternativa):**|A série temporal **é estacionária.**|
#
# **Um valor-p menor que 0.05 significa que podemos rejeitar a hipótese nula de que os dados da série temporal não são estacionários. Portanto, a série temporal é estacionária.**
#
# **Um valor-p maior que 0.05 significa que não rejeitamos a hipótese nula. Portanto, a série temporal não é estacionária.**

# %% [markdown]
# #### Executando o teste de estacionaridade para total de vendas por dia

# %%
# Running the ADF stationarity test
ts.test_stationarity(df_dummies.total_sales_per_day)
# Out:
# Resultado do Teste Dickey-Fuller:
#
# Estatística do Teste            -3.43
# Valor-p                          0.01
# Número de Lags Consideradas      3.00
# Número de Observações Usadas   321.00
# Valor Crítico (1%)              -3.45
# Valor Crítico (5%)              -2.87
# Valor Crítico (10%)             -2.57
# dtype: float64
#
# Conclusão:
#
# O valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.
# Essa série provavelmente é estacionária.

# %% [markdown]
# **Análise:**
#
# Como o Teste Dickey-Fuller Aumentado nos deu um valor-p inferior a 0.05, isso significa que a série temporal é estacionária. No entanto, ao observar os gráficos, podemos perceber que há claros indícios de sazonalidade. A média parece ser uma função do tempo, uma vez que flutua com a data.

# %% [markdown]
# ### 2.3.10. Applicability normality Test (Shapiro-Wilks Test)

# %% [markdown]
# Quando tomanos o nome teste de normalidade, ficamos confusos sobre como encontrar o melhor teste para saber se a variável segue uma distribuição normal. Existe muitos testes estatísticos, incluindo de correlação, regressão, teste t e análise de variância (ANOVA), assumem certas características sobre os dados, ou melhor, poussi estimativas de parâmetros. Assim, de fato os testes requerem que os dados segue uma **distribuição normal**. Esses testes são conhecidos de **testes paramétricos**, porque sua validade depende da distribuição dos dados.
#
# Ainda mais, antes de usar testes paramétricos devemos executar alguns testes preliminares para garantir que as suposições do teste sejam atendidas. Nos casos em que as suposições são violadas, testes não paramétricos são recomendados. É importante destacar que **os testes não paramétricos geralmente são menos poderosos do que os testes paramétricos correspondentes quando vigora a suposição de normalidade. Assim, é menos
# provável que você rejeite a hipótese nula quando ela é falsa se os dados vierem da distribuição
# normal.**
#
# > Os métodos não paramétricos são úteis quando a suposição de normalidade não se
# sustenta e seu tamanho da amostra é pequeno.
#
# É possível usar um **teste de significância** comparando a distribuição da amostra com a normal, com interesse de investigar se os dados mostram ou não um desvio śerio  de normalidade.
#
# Existem diversos métodos para o **teste de normalidade, como o teste de Shapiro-Wilk.** O método de Shapiro-Wilk é amplamente recomendado para teste de normalidade. É baseado na correlação entre os dados e as pontuações normais correspondentes, e é ele que utilizaremos em nossas análises a seguir. Este teste é uns dos mais popular para testar a normalidade dos dados.
#
# As hipóteses deste teste incluem:
#
# | Hipótese| Descrição do teste|
# |---|:-------------|
# | **H0 (Hipótese Nula):** |Os dados são normalmente distribuídos. Em outras palavras, as amostras vêm de uma distribuição normal. |
# | **H1 (Hipótese Alternativa):**|Os dados não são normalmente distribuídos. Caso contrário, a amostra não vem de uma distribuição normal.|
#
#
#
# Em poucas palavras, o teste de Shapiro-Wilk calcula se uma amostra aleatória de dados, segue uma distribuição normal. Quando o valor de **p é menor ou igual a 0.05 (assumindo um nível de confiança de 95%), os dados não são normais.** Portanto, se este teste falhar, você pode afirmar com 95% de confiança que seus dados não se encaixam  próximo de uma distribuição normal
#
# - Se o valor-p for **maior que 0.05** não rejeitamos a hipótese nula e podemos assumir a normalidade dos dados.
# - Se o valor-p for **menor que 0.05** rejeitamos a hipótese nula e **não** podemos assumir a normalidade dos dados.
#
# A implementação da função a seguir mostra o teste de normalidade e a distribuição das variables junto com teste.

# %%
shapiro_test(df_shapiro)
# Out:
# Approach : The p-value approach to hypothesis testing in the decision rule
#
# Variable: ['unitprice']
#
# H1 is accepted, which is in the 99.9% region of acceptance -> Null Hypothesis is rejected.
# SW-statistic: 0.6980526447296143	 p-value: 0.00000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['sales_amount']
#
# H1 is accepted, which is in the 99.9% region of acceptance -> Null Hypothesis is rejected.
# SW-statistic: 0.6735309362411499	 p-value: 0.00000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['sales_discount']
#
# H1 is accepted, which is in the 99.9% region of acceptance -> Null Hypothesis is rejected.
# SW-statistic: 0.6826182007789612	 p-value: 0.00000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['final_sales_price']
#
# ...

# %%
# Select the variables for test
df_shapiro = df_dummies.loc[:,["unitprice","sales_amount","sales_discount",
                               "final_sales_price","total_sales_per_day",
                               "total_sales_per_hour","avg_sales_per_day",
                               "avg_sales_per_hour","perc_return","sa","sd","tsd",
                               "tsh","avsd","avsh","SMA_3","SMA_5","MSD_3","MSD_5"]]
'''
Application of normalization using Function MinMaxScaler(), that is, transform the data
shapiro_scaled = pd.DataFrame(MinMaxScaler().fit_transform(df_shapiro), columns=df_shapiro.columns)

Apply the normality test
sw=stats_calc.shapiro_test(shapiro_scaled)

'''
# Apply the normality test
sw=stats_calc.shapiro_test(df_shapiro)

# Plot
graphic.plot_hist(df_shapiro)
# Out:
# Approach : The p-value approach to hypothesis testing in the decision rule
#
# Variable: ['unitprice']
#
# H1 is accepted at a 99.9% confidence level-> Null Hypothesis is rejected.
# SW-statistic: 0.6980526447296143	 p-value: 0.0000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['sales_amount']
#
# H1 is accepted at a 99.9% confidence level-> Null Hypothesis is rejected.
# SW-statistic: 0.6735309362411499	 p-value: 0.0000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['sales_discount']
#
# H1 is accepted at a 99.9% confidence level-> Null Hypothesis is rejected.
# SW-statistic: 0.6826182007789612	 p-value: 0.0000
#
# ----------------------------------------------------------------------------------------------------
# Variable: ['final_sales_price']
#
# H1 is accepted at a 99.9% confidence level-> Null Hypothesis is rejected.
# ...

# %% [markdown]
# **Análise:**
#
# De acordo com teste (Shapiro-Wilks) podemos ver que todas exceto (avg_sales_per_day and  avg_sales_per_hour) as variáveis não são normalmente distribuídas, pois a hipótese nula é rejeitada. **Tomando alfa como 0.05, os valores-p calculados do teste de Shapiro-Wilk são menores que alpha.** Em outra palavras, há fortíssimas evidências significativas, tomando nível de significância de 5%, para rejeitar a hipótese nula que os dados não segue uma distribuição normal, a probabilidade de erro ao fazermos tal afirmação é nula.
#
# Além disso, com base nesta análise gráfica, podemos dizer que a representação gráfica é fácil de entender, mas **testes estatísticos podem ser usados para chegar à conclusão com precisão e numericamente explica bem se alguém tiver um pingo de confusão na compreensão dos gráficos**.
#
# ---

# %% [markdown]
# Em síntese, podemos dizer que as duas suposições sobre a variável target passam aos testes de suposições, que é aceitável para análise de séries temporais. Isso é bom! Mas os testes de estacionariedade têm um enorme impacto em todas essas suposições.
#
# Nas próximas seções subsequentes, abordaremos análise de modelagem preditiva ao qual o problema é exposto a ser resolvido.

# %% [markdown]
# ### 3. Feature Selection
#
# *Tarefa mais difícil não é treinar a máquina, mas sim **engenhar variáveis que auxiliem no aprendizado**.*
#
# *References*
#
# https://matheusfacure.github.io/mltutorial/
#
# ---

# %% [markdown]
# ### 3.1 Declare o vetor de recursos e a variável de destino

# %%
# Colunas sem informações úteis ou com informações já derivadas serão descartadas.
cols = [col for col in df_dummies.columns if col not in ["date", "year", "month","day_of_week","total_sales_per_day"]]

# Separando a variável target (variável alvo), das features do conjunto de dados.
xFeatures, temp = df_dummies[cols], df_dummies["total_sales_per_day"]

# %% [markdown]
# ### 3.2. Feature Scaling

# %% [markdown]
# ### 3.2.1. O Que é Feature Scaling?

# %% [markdown]
# No mundo dos algoritmos de Machine Learning **funcionam melhor quando as variáveis de
# entrada são dimensionadas para um intervalo padrão.** Esse processo de dimensionamento ou  mudança de escala é chamado de **Feature Scaling.**
#
# Dessa maneira, isso inclui algoritmos que usam uma soma ponderada da entrada, como **regressão linear,  e algoritmos que usam medidas de distância, como k-vizinhos mais próximos (KNN).** As duas técnicas mais populares para dimensionar dados numéricos antes da modelagem  são a **normalização e a padronização**.
#
# Além do mais, o dimensionamento de recursos (Feature Scaling) consiste em transformar **os valores de  diferentes recursos numéricos para que caiam em um intervalo semelhante entre si. O  dimensionamento de recursos é usado para evitar que os modelos de aprendizado supervisionados sejam tendenciosos em relação a um intervalo específico de valores.**
#
#
# Por exemplo, se seu modelo é baseado em regressão linear e você não dimensiona
# recursos, alguns recursos podem ter um impacto maior do que outros, o que afetará o
# desempenho das previsões, dando vantagem indevida a algumas variáveis sobre outras. Isso  coloca certas classes em desvantagem durante o treinamento do modelo. É por isso que se torna  importante usar algoritmos de dimensionamento para que você possa padronizar seus valores  de recursos.
#
# Esse processo de dimensionamento de recursos é feito para que todos os recursos
# possam compartilhar a mesma escala e, portanto, evitar problemas como: **perda de precisão e  aumento no custo computacional à medida que os valores dos dados variam amplamente em diferentes ordens de magnitude.**
#
# > A ideia é **transformar** o valor dos recursos em um intervalo semelhante como outros para  que os algoritmos de Machine Learning se comportem melhor, resultando em modelos
# ideais.

# %% [markdown]
# ### <center>Normalização x Padronização</center>
#
# ### 3.2.2. Normalização
#
# A normalização é uma técnica frequentemente aplicada à preparação dos dados em Machine Learning, a normalização refere-se ao dimensionamento dos recursos para um intervalo de [0, 1] ou [-1, 1],  que é um caso especial de escalonamento mínimo-máximo. Para normalizar os dados, o  dimensionamento mínimo-máximo pode ser aplicado a uma ou mais colunas de recursos. Equação a seguir mostra como é feito normalização do dados com base no dimensionamento mínimo-máximo. O objetivo da normalização é alterar os valores das colunas numéricas no conjunto de dados para uma escala comum, sem distorcer as diferenças nos intervalos de valores.
#
#
# De acordo ( <a href ="https://ca.indeed.com/career-advice/career-development/normalization-formula" target="_bank"> Indeed Editorial Team, 2020)</a> afirma que a fórmula de normalização é uma fórmula estatística que você pode usar para reduzir um conjunto de dados para que todas as suas variações fiquem abaixo de um e zero. Ela ajuda você a **representar pontos de dados como valores entre um e zero. Os maiores dados têm um valor normalizado de um e o menor ponto de dados tem zero.** Os outros pontos de dados dentro de um e zero têm valores decimais em proporção às suas localizações dentro do intervalo do conjunto de dados. Essa técnica também ajuda a comparar valores normalizados correspondentes de vários conjuntos de dados para eliminar o efeito de variações na escala do conjunto de dados.
#
# ![image.png](attachment:d13a7fd0-5988-44cd-bf04-6de861d14d1d.png)
#
# > Source: <a href="https://developers.google.com/machine-learning/data-prep/transform/normalization" target="_bank" >Machine Learning Foundational courses </a>
#
# Assim temos:
#
# - X': Variável normalizada
#
# - X: Valor da variável
#
# - Xmin: valor mínimo da variável X
#
# - Xmax: valor máximo da variável X
#
#
# **Quando a Normalização é Importante?**
#
# >A normalização é principalmente necessária no caso de algoritmos que usam medidas
# de distância como clustering, sistemas de recomendação que usam semelhança de cosseno,
# etc. Isto é feito de forma que uma variável que está em uma escala maior não afeta o resultado  apenas porque está em uma escala maior. Em termos formais, essa técnica é aplicad quando o recurso é distribuído mais ou menos uniformemente em um intervalo fixo
#
#
# Alguns propriedade importantes quando devemos aplica dimensionamento (normalização) para um intervalo é uma boa opção quando ambas as seguintes condições são atendidas:
#
# - Você conhece os limites superiores e inferiores aproximados em seus dados com poucos ou nenhum valor discrepante.
#
# - Seus dados são distribuídos de maneira aproximadamente uniforme nesse intervalo.
#
# ---
#
# ### 3.2.2. Padronização
#
# Em medição, muitas vezes não estamos tão interessados em “quanto”, mas em “quão diferente da média”. A padronização, também chamada de **normalização**, coloca todas as variáveis em escalas semelhantes subtraindo a média e dividindo pelo desvio padrão; dessa forma, garantimos que uma variável não influencie excessivamente um modelo simplesmente devido à escala de sua medição original:
#
# Em outras palavras, padronização (ou normalização do Z-score ou em inglês Standardization ou ainda Standard Scaler) é o processo de redimensionamento dos recursos (variáveis) para que eles tenham as propriedades de uma distribuição normal com μ = 0 e σ = 1, onde μ é a média e σ é o desvio padrão da média; as pontuações padrão (também chamadas Z-score) das amostras  são calculadas da seguinte forma
#
# ![image.png](attachment:29e7db54-c7b1-4d80-9ddf-2d1b0ea13e7a.png)
#
# Source: (<a href="https://www.statisticshowto.com/probability-and-statistics/z-score/" target="_bank"> Z-Score: Definition, Formula and Calculation, 2023 </a> )
#
# Assim temos:
#
# - Zi: Valor padronizado no tensor <a href="https://www.ime.usp.br/~pf/algoritmos_para_grafos/aulas/footnotes/i-esimo.html" target="_bank"> [ i ]</a>
#
# - Xi: é um valor da variável na posição i, ou seja, variável aleatória
#
# - X barra: Média da amostra
#
# - S: Desvio padrão da amostra
#
# > **Z score:** é o quanto uma medida se afasta da média em termos de desvio-padrão, ou seja, é diferença entre um valor e a média, dividida pelo desvio-padrão. Em outros termos, **o desvio-padrão é a distância média da média, assim como, desvio-padrão mostrará como os dados estão distribuídos a partir da média, dessa maneira, com desvio-padrão obtemos uma visão mais ampla do conjunto de dados, em termos de “desvios-padrão o quão longe da média os dados apresentam”. Assim, o impacto de uma variável em um modelo não será afetado pela escala de sua medição original.**
#
#
# Em síntese, é importante ressaltar que os dados padronizados **representam a mesma informação**, mas a distribuição dos dados continua sendo **normalmente distribuída**, com média 0 e desvio padrão 1. Em outras palavras, normalizar os dados NÃO padroniza os dados. A padronização simplesmente coloca os dados no mesmo intervalo da distribuição normal padrão, geralmente para fins de comparação.
#
# #### Quando a Padronização é Importante?
#
# > A pradonização funciona melhor quando a variável segue uma Distribuição normal. A padronização pressupõe que seus dados tenham uma distribuição gaussiana (curva de sino). Isso não precisa ser estritamente verdade, mas a técnica é mais eficaz se sua distribuição de atributos for gaussiana. A padronização é útil quando seus dados têm escalas variadas e o algoritmo que você está usando faz suposições sobre seus dados terem uma distribuição gaussiana.
#
#
# ---
#
# Normalização e padronização são **ideias semelhantes**, mas possuem algumas diferenças importantes. A **normalização** é o processo de normalizar um intervalo de dados. É a série de processos que os cientistas usam para atingir escalas entre **um e zero**. Essa técnica também coloca pontos de dados dentro do intervalo de dados para o intervalo **máximo e mínimo.** Como alternativa, a **padronização** usa desvio padrão para representar a distribuição de pontos de dados. Ele também relaciona o ponto de dados com a média ou a média de todos os pontos de dados.
#
# Por exemplo, calcular um escore z é um processo de padronização, pois você pode **superdimensionar os resultados fora do intervalo de um a zero.** Novamente, enquanto uma técnica de normalização **converte valores em um intervalo de dados para caber em um determinado intervalo, mais frequentemente de um para zero**, a padronização transforma os mesmos valores para caber em uma distribuição que contém **média zero e desvio padrão um.** Você pode chamar esse processo de centralização média ou cálculo de Z-score.
#
#
# Ambas as técnicas têm suas desvantagens. Se você tiver valores outliers em seu
# conjunto de dados, a Normalização dos dados certamente aumentará os dados "normais" para  um intervalo muito pequeno. E, geralmente, a maioria dos conjuntos de dados tem outliers. Ao  usar a Padronização, seus novos dados não são limitados (ao contrário da Normalização). Portanto, a normalização é geralmente evitada quando o conjunto de dados tem outliers (desde que inclua o valor máximo). Nesses casos, preferimos a padronização.**A normalização geralmente significa redimensionar uma variável para ter valores entre um intervalo desejado (como [-1,1] ou [0,1]) enquanto a padronização transforma os dados para ter uma média de zero e um desvio padrão de 1. Vantagem da Normalização sobre Padronização é que não estamos vinculados a nenhuma distribuição específica. Além disso, a Normalização também suprime o efeito de outliers até certo ponto.**
#
#
# ---
# #### Algumas considerações importantes:
#
# 1. A Normalização torna o treinamento menos sensível à escala de recursos, para que possamos resolver melhor os coeficientes.
#
# 2. O uso de um método de Normalização melhorará a análise de múltiplos modelos.
#
# 3. A Normalização assegurará que um problema de convergência não tenha uma variância massiva, tornando a otimização viável.
#
# 4. A Padronização tende a tornar o processo de treinamento bem melhor, porque a condição numérica dos problemas de otimização é melhorada.
#
# ---
#
# Se você decidir normalizar ou padronizar seus dados, lembre-se do seguinte:
#
# - Um conjunto de dados normalizado sempre terá valores que variam entre 0 e 1 ou [-1, 1].
#
# - Um conjunto de dados padronizado terá uma média de 0 e desvio padrão de 1, mas não há limite superior ou inferior específico para os valores máximo e mínimo.
#
#
#
# Portanto, a tabela abaixo simplifica cada detalhe dessas duas técnicas.
#
# | |Normalização |Padronização|
# |---:|:-------------|:-----------|
# ||**O valor mínimo e máximo dos recursos são usados para dimensionamento**|**A média e o desvio padrão são usados para dimensionamento.**|
# ||**É usado quando os recursos são de escalas diferentes.**| **É usado quando queremos garantir média zero e desvio padrão unitário.**|
# ||**Escala valores entre [0, 1] ou [-1, 1].**| **Não está limitado a um determinado intervalo.**|
# ||**É realmente afetado por outliers**|**É muito menos afetado por outliers**|
# ||**Essa transformação comprime os dados n-dimensionais em um hipercubo de unidade n-dimensional.**|**Ele traduz os dados para o vetor médio dos dados originais para a origem e compacta ou expande.**|
# ||**É útil quando não sabemos sobre a distribuição**|**É útil quando a distribuição de recursos é Gaussiana.**|
# ||**É frequentemente chamado de Normalização de Escala**|**É frequentemente chamado de Normalização Z-Score.**|

# %% [markdown]
# ### 3.3. Preparing the data for Feature Selection and Normalization

# %% [markdown]
# Primeiro, vamos pré-processar os dados em um formato que uma rede neural pode ingerir. Isto é fácil: os dados já são numéricos, então você não precisa fazer nenhuma vetorização.
#
# Vamos normalizar nossa série temporal usando algoritmo XGBoost para seleção de atributos.

# %% [markdown]
# ### 3.3.1. Algoritmo XGBoost Feature Importance

# %% [markdown]
# **Parâmetro:**  importance_type
#
# - **weight:** o número de vezes que um recurso (variável) é usado para dividir os dados em todas as árvores.
#
# - **gain:** o ganho médio em todas as divisões em que o recurso é usado.
#
# - **cover:** a cobertura média em todas as divisões em que o recurso é usado.
#
# - **total_gain:** o ganho total em todas as divisões em que o recurso é usado.
#
# - **total_cover:** a cobertura total em todas as divisões em que o recurso é usado.
#
# A implementação da função a seguir, seleciona the scores das melhores variáveis para treinar o modelo.

# %%
# function call Feature Importance
xbg_best_features = dl_and_ml.feature_imp(features=pd.DataFrame(MinMaxScaler().fit_transform(xFeatures), index=xFeatures.index, columns=xFeatures.columns),
#xbg_best_features = dl_and_ml.feature_imp(features=xFeatures / 1e6,
                      target=temp,
                      param_imp='gain',
                      n_best_features=4)

# Capturing k best variables for model training
xbg_best_features
# Out:
#                       score_XGBRFRegressor
# discount                    767,937,024.00
# SMA_5                       137,131,568.00
# SMA_3                       117,544,888.00
# total_sales_per_hour         88,387,104.00

# %%
# Creating new dataframe with k principais recursos
X = xFeatures.loc[:,xbg_best_features.index]
X["total_sales_per_day"] = temp

# Application of normalization using Function MinMaxScaler(), that is, transform the data
X_scaled = pd.DataFrame(MinMaxScaler().fit_transform(X), index=X.index, columns=X.columns)
X_scaled.head()
# Out:
#             discount  SMA_5  SMA_3  total_sales_per_hour  total_sales_per_day
# date
# 2019-03-01      1.00   0.55   0.48                  0.38                 0.38
# 2019-03-02      1.00   0.50   0.45                  0.34                 0.34
# 2019-03-03      1.00   0.44   0.46                  0.29                 0.29
# 2019-03-04      1.00   0.41   0.33                  0.31                 0.31
# 2019-03-05      1.00   0.41   0.30                  0.31                 0.31

# %% [markdown]
# No entanto, escalamos os dados pelo fator de notação científica de 1e6 para garantir que os valores estejam próximos da faixa de [ 0 - 1 ]; isso funciona bem com a inicialização de peso padrão e a learning rate:

# %%
X_scaled_1e6 =  X / 1e6
X_scaled_1e6.head()
# Out:
#             discount  SMA_5  SMA_3  total_sales_per_hour  total_sales_per_day
# date
# 2019-03-01      0.00   0.01   0.01                  0.01                 0.01
# 2019-03-02      0.00   0.01   0.01                  0.01                 0.01
# 2019-03-03      0.00   0.01   0.01                  0.01                 0.01
# 2019-03-04      0.00   0.01   0.01                  0.01                 0.01
# 2019-03-05      0.00   0.01   0.01                  0.01                 0.01

# %% [markdown]
# ### 4. Train/Test Split

# %% [markdown]
# Em todos os nossos experimentos, usaremos os primeiros 50% dos dados para treinamento, os 25% seguintes para validação e os últimos 25% para teste. Ao trabalhar com séries temporais dados, é importante usar dados de validação e teste mais recentes do que os dados de treinamento, porque você está tentando prever o futuro com base no passado, não o contrário, e suas divisões de validação/teste devem refletir isso. Alguns problemas são consideravelmente mais simples se você inverter o eixo do tempo!

# %%
def train_val_split(dataset, train_size=None,valid_and_test= None):
    
    num_train_samples = int(train_size * len(dataset))
    num_val_samples   = int(valid_and_test * len(dataset))
    num_test_samples  = len(dataset) - num_train_samples - num_val_samples

    # Divide the time series into training and validation set
    time_train = dataset[0:num_train_samples]
    time_valid = dataset[num_train_samples:num_train_samples + num_val_samples]
    time_test =  dataset[num_train_samples + num_val_samples:]
    
    return time_train, time_valid , time_test

# Function call
mulvar_train, mulvar_valid , mulvar_test =train_val_split(dataset= X_scaled_1e6, train_size=0.5,valid_and_test=0.25)
mulvar_train.shape, mulvar_valid.shape, mulvar_test.shape
# Out:
# ((162, 5), (81, 5), (82, 5))

# %% [markdown]
# ### <center>5. Predictive Modeling</center>
#
#
# Mediante o exposto nas seções anteriores, analisaremos agora como as inferências são realizadas com  **algoritmos Machine Learning e Deep Learning** para demonstrar seu respectivo valor de **inferência** aos resultados da mineração de dados.
#
# ------

# %% [markdown]
# ### 5.1 Regression loss function

# %% [markdown]
# Em redes neurais, **uma função de perda é usada na otimização dos valores de peso de um modelo.** Uma função de perda realiza o mapeamento das decisões para seus pesos associados. A função de perda também é conhecida como a **função de erro.**
#
# **Uma função de custo geralmente é uma perda média para todo o conjunto de dados usado para treinar o modelo.** Mas uma função de perda geralmente é **usada para um único exemplo no conjunto de dados de treinamento**. Embora a função de perda e as funções de custo sejam intercambiáveis ou usadas como sinônimos uma da outra, elas são, na verdade, diferentes.
#
# Em outras palavras, as funções de perda quantificam o quão próxima uma determinada rede neural está do ideal para o qual ela está sendo treinada.**A ideia é simples, calculamos uma métrica com base no erro que observamos nas previsões da rede. Em seguida, agregamos esses erros em todo o conjunto de dados e calculamos a média deles e agora temos um único número representativo de quão próximo o
# rede neural está em seu ideal.**
#
# - Procurar este estado ideal equivale a encontrar os parâmetros (pesos e vieses) que irão minimizar a “perda” incorrida (cometeu) com os erros. Dessa forma, as funções de perda ajudam a reformular o treinamento de redes neurais como um problema de otimização. Na maioria dos casos, esses parâmetros não podem ser resolvidos analiticamente, mas, na maioria das vezes, podem ser bem aproximados com algoritmos de otimização iterativos, como gradiente descendente.
#
# Vamos recapitular alguns pontos-chave do capítulo:
#
# **Função de perda:** Avalia o quão bem ela classifica (minimiza o erro) em cada etapa
#
# **Função de otimização:** Orienta-o para os pontos de menor erro
#
# > A função de perda resume a diferença entre desejado e previsto, sejam eles vetores, em um único número.
#
# Em termos conceituais, perdas e métricas não são a mesma coisa: as perdas são utilizadas para **treinar um modelo**. Dessa forma, elas devem ser diferenciáveis (pelo menos, quando são avaliadas). Além do mais, não tem problema se elas não forem facilmente interpretáveis por humanos. Em contrapartida, **as métricas são usadas para avaliar um modelo: elas devem ser mais facilmente interpretáveis e podem não ser diferenciáveis**

# %% [markdown]
# ### 5.2. A common-sense, non-machine-learning baseline

# %% [markdown]
# Antes de começarmos a usar os modelos de **Deep Learning** que são considerados  caixas pretas para resolver o problema de previsão de demanda vendas, vamos tentar usa abordagem simples e de bom senso. Ela servirá como uma verificação de sanidade e estabelecerá uma **linha de base** que teremos que vencer para demonstrar a utilidade dos modelos de Machine Learning mais avançados.
#
# Essas linhas básicas de bom senso podem ser úteis quando você está abordando um novo problema para o qual não há solução conhecida (ainda). Um exemplo clássico é o de tarefas de classificação desbalanceadas, onde algumas classes são muito mais comuns do que outras. Se seu conjunto de dados contiver 90% de instâncias da classe A e 10% de instâncias da classe B, uma abordagem de bom senso para
# a tarefa de classificação é sempre prever “A” quando apresentada a uma nova amostra. Esse classificador tem 90% de precisão geral e, portanto, qualquer abordagem baseada em aprendizado deve bater essa pontuação de 90% para demonstrar utilidade. Às vezes, essas linhas de base elementares podem ser surpreendentemente difíceis de superar.
#
# Nesse caso, as séries temporais de demanda de vendas por dias podem ser seguramente consideradas contínuas **(as vendas de amanhã provavelmente estarão próximas das vendas de hoje)**, bem como periódicas com um período diário. Assim, uma abordagem de bom senso é sempre prever que a demanda de vendas por brinquedos daqui a 24 horas será igual à demanda de agora. Vamos avaliar essa abordagem, usando a métrica de Erro Absoluto Médio (MAE), definida da seguinte forma:
#
# **The Mean absolute error (MAE)**, também conhecido como perda L1, é uma das funções de perda mais simples e, é uma métrica de avaliação fácil de entender em modelos de regressão. Calculamos o resíduo para cada ponto de dados, tomando apenas o valor absoluto de cada um para que os **resíduos negativos e positivos não se anulem.** Em seguida, calculamos a média de todos esses resíduos.Assim como, MAE mede apenas a magnitude dos erros e não se preocupa com sua direção. Quanto menor o MAE, maior a precisão de um modelo.
#
# Em outras palavras, MAE mede a magnitude média dos erros em um conjunto de previsões, **sem considerar sua direção**. Partindo desse pressuposto que, **o MAE é a média sobre a amostra da verificação dos valores absolutos das diferenças entre a previsão e a observação correspondente.** Assim , pode-se então afirma que o MAE é uma pontuação linear, o que significa que todas as diferenças individuais são ponderadas igualmente na média. Saiba mais <a href="https://resources.eumetrain.org/data/4/451/english/msg/ver_cont_var/uos3/uos3_ko1.htm" target="bank">Mean Absolute Error (MAE)</a>, a equação formal é mostrada abaixo.
#
#
# ![image.png](attachment:abeec097-ac80-4785-a171-2006537c5a8f.png)
#
# Source: <a href="https://www.dataquest.io/blog/understanding-regression-error-metrics/" target="_bank"> DATAQUEST, 2018</a>
#
# No entanto, se o valor absoluto não for obtido (os sinais dos erros não forem removidos), o erro médio torna-se o erro de viés médio (MBE) e geralmente é destinado a medir o viés médio do modelo. O MBE pode transmitir informações úteis, mas deve ser interpretado com cautela porque os erros positivos e negativos serão anulados. <a href="https://medium.com/human-in-a-machine-world/mae-and-rmse-which-metric-is-better-e60ac3bde13d" target="_bank">MAE and RMSE — Which Metric is Better?</a>
#
# **Lembrete:**
#
# **O  módulo  (ou valor absoluto) de um número sempre retorna retorno *seu valor positivo*. Rigorosamente:**
#
#     se A => 0, então  |A| =  A
#     se A <  0, então  |A| = -A
#
# Desse modo:
#
# - **|3|** = 3
#
# - **|-54|** =  54
#
# - **|-0,273|** = 0,273
#
# **Termos-chave:**
#
# **Erro Médio Absoluto (sigla MAE, em inglês)** também chamado de **Desvio Médio Absoluto**. É a soma da diferença absoluta entre previsões e valores reais. Dessa maneira, formenta a ideia de quão erradas estão nossas previsões. Portanto, valor igual a 0 indica que não há erro, sendo a previsão perfeita (o que é difícil de acontecer).
#
# De modo menos formal, quando subtraímos os valores previstos dos valores reais, obtendo os erros, somamos os valores absolutos desses erros e obtemos sua **média**. Essa métrica dá uma noção do erro geral para cada previsão do modelo, quanto menor (mais próximo de 0) melhor.
#
#
# ---

# %% [markdown]
# ### 5.3. Preparing the Data for Machine Learning Models

# %% [markdown]
# Nosso objetivo será prever o total de vendas de brinquedos de amanhã com base no número de demanda das últimas 7 semanas de dados (49 dias), ou seja, 7x7. As entradas para o nosso modelo serão, portanto, **sequências (geralmente uma única sequência por dia quando o modelo estiver em produção)**, cada uma contendo 49 valores das etapas de tempo t – 48 a t. Para cada sequência de entrada, o modelo produzirá um único valor: a previsão para a etapa de tempo t + 1.
#
# Em outras palavras, vamos criar um objeto Dataset que produz lotes de dados dos últimos 49 dias juntamente com total de vendas por dia (target) no futuro. Porque as amostras do conjunto de dados são altamente redundantes (amostra N e amostra N + 1 terão a maior parte de seus passos de tempo em comum), seria um desperdício alocar memória explicitamente para cada amostra.</mark>

# %% [markdown]
# ### 5.4. Forecasting Using a Sequence-to-Sequence Model

# %% [markdown]
# Em primeira instância,  vamos criar uma RNN que prevê as próximas 14 etapas em cada intervalo de tempo. Isto é, em vez de apenas prever intervalos de tempo 49 a 56 com base nos intervalos de tempo 0 a 48, ele irá prever intervalos de tempo 1 a 14 no intervalo de tempo 0, depois intervalos de tempo 2 a 15 no intervalo de tempo 1 e assim por diante, e finalmente ele irá prever intervalos de tempo 49 a 56 no último intervalo de tempo. Observe que o modelo é causal: quando faz previsões em qualquer intervalo de tempo, ele só pode ver os **intervalos de tempo anteriores.**
#
# Dessa maneira, isso significa que haverá muito mais gradientes de erro fluindo pelo modelo e eles não precisarão fluir tanto no tempo, pois virão da saída de cada etapa de tempo, não apenas da última. **Isso estabilizará e acelerará o treinamento.**
#
# No entanto, para ser mais específico, no intervalo de tempo 0, o modelo produzirá um vetor contendo as previsões para os intervalos de tempo 1 a 14, então, no intervalo de tempo 1, o modelo irá prever os intervalos de tempo 2 a 15 e assim por diante. Em outras palavras, os alvos são sequências de janelas consecutivas, deslocadas em uma etapa de tempo a cada etapa de tempo. O alvo não é mais um vetor, **mas uma sequência do mesmo comprimento que as entradas, contendo um vetor de 14 dimensões a cada passo.**
#
# Além do mais, a preparação dos conjuntos de dados não é trivial, pois cada instância tem uma janela como entrada e uma sequência de janelas como saída. Uma maneira de fazer isso é usar a função utilitária to_windows() para obter janelas de janelas consecutivas.

# %% [markdown]
# ### 5.5. Instantiating datasets for training, validation, and testing

# %% [markdown]
# A implementação da função a seguir prepara os conjuntos de dados para o nosso modelo sequência a sequência. Ela também cuidará do embaralhamento (opcional) e do tamanho do batch: Antes disso, você pode aprender mais sobre os detalhes específico das funções nas seções subsequentes no livro: Hands-on: Machine Learning with Scikit-Learn & TensorFlow, 3nd and Deep Learning with Python, 2nd.

# %%
""""A named constant is a name that represents a value that cannot be 
changed during the program's execution."""

# Using Global Constants Defining Named Constants
SEQ_LENGTH = 49
BATCH_SIZE = 5
NUM_FEATURES = X_scaled_1e6.shape[-1]
SN = 1e6 #scientific notation factor of 1e6

def to_windows(dataset, length):
    dataset = dataset.window(length, shift=1, drop_remainder=True)
    return dataset.flat_map(lambda window_ds: window_ds.batch(length))

def to_seq2seq_dataset(series,ahead, seq_length=SEQ_LENGTH,target_cols=1,batch_size=BATCH_SIZE,
    shuffle=False, seed=None):
    
    ds = to_windows(tf.data.Dataset.from_tensor_slices(series), ahead + 1)
    ds = to_windows(ds, seq_length).map(lambda S: (S[:, 0], S[:, 1:, 1]))
    if shuffle:
        ds = ds.shuffle(8 * batch_size, seed=seed)
    return ds.batch(batch_size)

# %% [markdown]
# Agora podemos usar esta função para criar os conjuntos de dados:

# %%
#seq2seq_train = to_seq2seq_dataset(mulvar_train, shuffle=True, seed=42)
#seq2seq_valid = to_seq2seq_dataset(mulvar_valid)

seq2seq_train = to_seq2seq_dataset(mulvar_train,ahead=14, shuffle=True, seed=42).cache()
seq2seq_valid = to_seq2seq_dataset(mulvar_valid,ahead=14).cache()
seq2seq_test  = to_seq2seq_dataset(mulvar_test, ahead=14).cache()

# %% [markdown]
# ### 5.6. Creating a function for TensorBoard

# %% [markdown]
# o TensorBoard é uma ótima ferramenta de visualização interativa que você pode usar para visualizar as curvas de aprendizado durante o treinamento, compará-las com suas diversas execuções, visualizar o grafo computacional, as imagens geradas pelo seu modelo, os dados multidimensionais complexos projetados em 3D e clusterizados de modo automático, analisar as estatísticas de treinamento e muito mais! Ela vem automaticamente instalada quando você instala o TensorFlow, ou seja, você já tem ela em mãos.
#
# Dessa forma, criaremos um diretório de root log que usaremos para nossos logs do TensorBoard, além de uma pequena função que gerará um caminho de subdiretório com base na data e hora atuais, de modo que seja diferente a cada execução. Convém incluir informações adicionais no nome do diretório de log, como os valores de hiperparâmetro que você está testando, para facilitar o entendimento do que você está vendo no <a href="https://www.tensorflow.org/tensorboard/" target ="_bank"> TensorBoard<a/>

# %%
# Setting log path
root_logdir = os.path.join(os.curdir, "world_of_comics_logs")

def get_run_logdir(root_logdir="logs"):
    return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")

def name_logdir(name):
    
    # Increment every time you train the model
    run_index = 1 
    run_logdir = Path() / "world_of_comics_logs" / f"{name}"
    
    # Return Callback TensorBoard()
    return tf.keras.callbacks.TensorBoard(run_logdir)

# Function call
run_logdir = get_run_logdir()
run_logdir
# Out:
# PosixPath('logs/run_2023_10_09_08_09_08')

# %% [markdown]
# ### 5.7. Create an function for Model training

# %%
def fit_and_evaluate(model,train_set, valid_set, learning_rate, filepath, logdir, epochs=None):
    
    # Create an list of callbacks
    
    # We'll use a callback to stop training when our performance metric reaches a specified level.
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae",
        #mode='min', 
        patience=50, 
        restore_best_weights=True,
    )
    # We use a callback to save the best performing model.
    model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath= filepath,
        save_weights_only=True,
        monitor='val_mae',
        #mode='min',
        save_best_only=True,
    )
    # To define a List of callbacks to use
    callbacks = [early_stopping_cb,model_checkpoint_cb,name_logdir(logdir),TqdmCallback(verbose=0)]
    
    # Compile the model
    model.compile(loss=tf.keras.losses.Huber(), 
                  optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
                  metrics=["mae", "mape", "mse" ,"msle"]
    )
    # Fit the model
    history = model.fit(train_set, validation_data=valid_set, epochs=epochs,
                        verbose = 0,
                        callbacks=callbacks,
    )
    # Evaluate
    # zip “pairs” elements from a series of lists, tuples, or other sequences to create a list of tuples:
    data = list(zip(model.metrics_names, model.evaluate(valid_set)))

    # Returns dataframe with values of metrics calculated by the model
    return  pd.DataFrame(data, columns=['Metrics','Score'])

# %% [markdown]
# ### 5.8. Creating a function to evaluate the model

# %%
def predictions(model,dataset_valid,dataset_test,target,seq2seq_valid, seq2seq_test, ahead, seq_length=SEQ_LENGTH):
    
    # Evaluation  the Model
    print('Forecast in Data Validation')
    for i in range(ahead):
        preds = pd.Series(model.predict(seq2seq_valid)[:-1, -1, i],
                          index=dataset_valid.index[seq_length + i : -ahead + i])
        mae = (preds - dataset_valid[target]).abs().mean() * SN
        print(f"MAE for + {i + 1}: {mae:,.0f}")
    print('\n')
    
    print('Forecast in Data Test')
    for i in range(ahead):
        preds = pd.Series(model.predict(seq2seq_test)[:-1, -1, i],
                          index=dataset_test.index[seq_length + i : -ahead + i])
        mae = (preds - dataset_test[target]).abs().mean() * SN
        print(f"MAE for +{i + 1}: {mae:,.0f}")
    
    # Reverse transformation
    result_valid = list(zip(model.metrics_names, model.evaluate(seq2seq_valid)))
    result_valid= pd.DataFrame(result_valid, columns=['metrics','score'])
    result_test = list(zip(model.metrics_names, model.evaluate(seq2seq_test)))
    result_test= pd.DataFrame(result_test, columns=['metrics','score'])
    
   
    # Creating a new dataframe to calculate difference
    diff= pd.DataFrame({'Metrics_on_Validation_Data':result_valid['score'] * SN,
                        'Metrics_on_Test_Data':result_test['score'] * SN,
                        'Difference':abs(result_valid['score'] - result_test['score']) * SN,
                        'Mean':((result_valid['score']  + result_test['score']) / 2) * SN
                         })
    '''
    diff= pd.DataFrame({'Metrics_on_Validation_Data':result_valid['score'],
                        'Metrics_on_Test_Data':result_test['score'],
                        'Difference':abs(result_valid['score'] - result_test['score']),
                        'Mean':(result_valid['score'] + result_test['score']) / 2 
                         })
    '''

    # Alter names of index
    diff.rename(index = {0:'loss',1:'mae',2:'mape',3:'mse',4:'msle'}, inplace = True)
    
    # Return the difference between dataframes
    return diff

# %% [markdown]
# ### 6. Recurrent Neural Networks

# %% [markdown]
# Existe uma família de arquiteturas de redes neurais projetadas especificamente para este caso de uso: **Redes neurais Recorrentes**. Entre elas, a camada Long Short Term Memory (LSTM) and GRUs (Gated Recurrent Units) tem sido muito popular em aplicabilidade em systema de Inteligência Artificial.
#
# No entanto, você pode aprender mais sobre todas as caracaterísticas dessa arquitetura nos livros a seguir:
#
# Applied Deep Learning
#
# Deep Learning A Practitioner’s Approach, 2E
#
# Deep Learning with Python, 2E
#
# Hands-on: Machine Learning with Scikit-Learn & TensorFlow, 3E
#
# Practical Mathematics for AI and Deep Learning
#
# ---

# %% [markdown]
# ### 6.1. Model LSTM with Stacking recurrent layers using method Seq2Seq

# %% [markdown]
# Agora, podemos construir o modelo sequência a sequência:

# %%
# Resets all state generated by Keras.
tf.keras.backend.clear_session()

# Ensures reproducibility
tf.random.set_seed(42)

lstm_seq2seq= tf.keras.models.Sequential([
      tf.keras.Input(shape=[SEQ_LENGTH, NUM_FEATURES]),
      tf.keras.layers.LSTM(32, return_sequences=True, unroll=True),
      #tf.keras.layers.LSTM(64, return_sequences=True, unroll=True),
      #tf.keras.layers.LSTM(96, return_sequences=True, unroll=True),
      tf.keras.layers.Dense(14), # no activation function by default
]) 

# Model summary
lstm_seq2seq.summary()

# Train the model
fit_and_evaluate(model=lstm_seq2seq,
                 train_set=seq2seq_train, 
                 valid_set=seq2seq_valid,
                 learning_rate=1e-3,
                 epochs=1000,
                 logdir="lstm",
                 filepath="models/lstm_seq2seq.h5"
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 49, 32)            4864
#
#  dense (Dense)               (None, 49, 14)            462
#
# ...
# Total params: 5,326
# Trainable params: 5,326
# Non-trainable params: 0
# _________________________________________________________________
# 0epoch [00:00, ?epoch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0046s vs `on_train_batch_end` time: 0.0220s). Check your callbacks.
# 2/2 [==============================] - 0s 20ms/step - loss: 1.7603e-06 - mae: 0.0015 - mape: 18.3383 - mse: 3.5205e-06 - msle: 3.4525e-06
#   Metrics  Score
# 0    loss   0.00
# 1     mae   0.00
# 2    mape  18.34
# 3     mse   0.00
# 4    msle   0.00

# %%
# Create data sequence from last date of our original series
dates_future= [mulvar_test.index[-1] + DateOffset(days = x) for x in range(0, 15)]
dates_future
# Out:
# [Timestamp('2020-01-31 00:00:00'),
#  Timestamp('2020-02-01 00:00:00'),
#  Timestamp('2020-02-02 00:00:00'),
#  Timestamp('2020-02-03 00:00:00'),
#  Timestamp('2020-02-04 00:00:00'),
#  Timestamp('2020-02-05 00:00:00'),
#  Timestamp('2020-02-06 00:00:00'),
#  Timestamp('2020-02-07 00:00:00'),
#  Timestamp('2020-02-08 00:00:00'),
#  Timestamp('2020-02-09 00:00:00'),
#  Timestamp('2020-02-10 00:00:00'),
#  Timestamp('2020-02-11 00:00:00'),
#  Timestamp('2020-02-12 00:00:00'),
#  Timestamp('2020-02-13 00:00:00'),
#  Timestamp('2020-02-14 00:00:00')]

# %% [markdown]
# ### 6.1.1. Model Evaluation and Predictions in Test

# %%
# Predictions
X_pred = mulvar_test.to_numpy()[np.newaxis, :SEQ_LENGTH]
pd.DataFrame(lstm_seq2seq.predict(X_pred)[0, -1]  * 1e6, index=dates_future[1:], columns=['Forecast total sales per day for the next 14 days'])
# Out:
# 1/1 [==============================] - 0s 13ms/step
#             Forecast total sales per day for the next 14 days
# 2020-02-01                                          13,438.98
# 2020-02-02                                          13,902.82
# 2020-02-03                                          13,608.84
# 2020-02-04                                          13,240.38
# 2020-02-05                                          13,408.36
# 2020-02-06                                          12,671.22
# 2020-02-07                                          12,240.19
# 2020-02-08                                          11,632.97
# 2020-02-09                                          12,092.96
# 2020-02-10                                          11,789.26
# 2020-02-11                                          11,198.77
# 2020-02-12                                          10,687.62
# 2020-02-13                                          10,553.32
# ...

# %%
# Average value of total sales per day
print(f'R$: {temp.mean():,.2f}')
# Out:
# R$: 9,842.21

# %% [markdown]
# Forecast total sales per day for the next 14 days

# %%
# Evaluate the model
predictions(model =lstm_seq2seq,
           dataset_valid=mulvar_valid,
           dataset_test= mulvar_test,
           target='total_sales_per_day',
           seq2seq_valid= seq2seq_valid,
           seq2seq_test= seq2seq_test,
           ahead=14,
)
# Out:
# Forecast in Data Validation
# 2/2 [==============================] - 0s 21ms/step
# MAE for + 1: 1,950
# 2/2 [==============================] - 0s 22ms/step
# MAE for + 2: 1,847
# 2/2 [==============================] - 0s 23ms/step
# MAE for + 3: 1,843
# 2/2 [==============================] - 0s 18ms/step
# MAE for + 4: 1,915
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 5: 1,883
# 2/2 [==============================] - 0s 18ms/step
# MAE for + 6: 2,067
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 7: 2,295
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 8: 3,062
# 2/2 [==============================] - 0s 21ms/step
# MAE for + 9: 2,700
# 2/2 [==============================] - 0s 23ms/step
# MAE for + 10: 2,835
# 2/2 [==============================] - 0s 22ms/step
# MAE for + 11: 2,901
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 12: 2,979
# 2/2 [==============================] - 0s 24ms/step
# ...

# %% [markdown]
# Se você avaliar as previsões desse modelo para t + 1, encontrará um erro MAE em teste de **R$ 3,090**, corresponde valor médio de vendas por dia. Para **t + 2 é 3.379** o desempenho do modelo continua a cair gradualmente à medida que o modelo tenta prever mais no futuro. No t + 14, o **MAE é 4,810** e assim por diante. Logo, as previsões do modelo tem uma boa taxa de assertividade em um horizonte no máximo de 5 dias, isso corresponde os erros das 5 previsões em validação.
#
# Porém, se você sempre assumir que **total de vendas por dia de toys** será a mesma de agora, você estará errado **em R$ 1,843.88 em média, não é tão ruim!** Assim como, é um valor relativamente (severamente) pequeno em comparação com a média do total de vendas por dia, ou seja, **9,842 reais.**
#
# No entanto, MAPE afirma que as previsões do nosso modelo estão erradas, **em média, 21% abaixo do valor real**.

# %% [markdown]
# ### 6.2. Model BI-LSTM Stacking recurrent layers using method Seq2Seq

# %%
# Ensures reproducibility
tf.random.set_seed(42)

# Ensures reproducibility
tf.random.set_seed(42)

# Define a sequential model
lstm_bi_seq2seq= tf.keras.models.Sequential([
      tf.keras.Input(shape=[SEQ_LENGTH, NUM_FEATURES]),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, unroll=True)),
      #tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, unroll=True)),
      #tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(96, return_sequences=True, unroll=True)),
      tf.keras.layers.Dense(14),
]) 
# Model summary
lstm_bi_seq2seq.summary()

# Train the model
fit_and_evaluate(model=lstm_bi_seq2seq, 
                 train_set=seq2seq_train, 
                 valid_set=seq2seq_valid,
                 learning_rate=1e-3,
                 epochs=1000,
                 logdir="lstm_bi",
                 filepath="models/lstm_bi_seq2seq.h5",
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  bidirectional (Bidirectiona  (None, 49, 64)           9728
#  l)
#
#  dense_1 (Dense)             (None, 49, 14)            910
#
# ...
# Total params: 10,638
# Trainable params: 10,638
# Non-trainable params: 0
# _________________________________________________________________
# 0epoch [00:00, ?epoch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0059s vs `on_train_batch_end` time: 0.0483s). Check your callbacks.
# 2/2 [==============================] - 0s 17ms/step - loss: 5.0654e-07 - mae: 6.6163e-04 - mape: 8.5533 - mse: 1.0131e-06 - msle: 9.9640e-07
#   Metrics  Score
# 0    loss   0.00
# 1     mae   0.00
# 2    mape   8.55
# 3     mse   0.00
# 4    msle   0.00

# %%
# Evaluate the model
predictions(model =lstm_bi_seq2seq,
           dataset_valid=mulvar_valid,
           dataset_test= mulvar_test,
           target='total_sales_per_day',
           seq2seq_valid= seq2seq_valid,
           seq2seq_test= seq2seq_test,
           ahead=14,
)
# Out:
# Forecast in Data Validation
# 2/2 [==============================] - 0s 17ms/step
# MAE for + 1: 1,945
# 2/2 [==============================] - 0s 17ms/step
# MAE for + 2: 1,952
# 2/2 [==============================] - 0s 16ms/step
# MAE for + 3: 2,173
# 2/2 [==============================] - 0s 17ms/step
# MAE for + 4: 2,432
# 2/2 [==============================] - 0s 17ms/step
# MAE for + 5: 2,779
# 2/2 [==============================] - 0s 16ms/step
# MAE for + 6: 3,131
# 2/2 [==============================] - 0s 17ms/step
# MAE for + 7: 3,151
# 2/2 [==============================] - 0s 22ms/step
# MAE for + 8: 3,389
# 2/2 [==============================] - 0s 19ms/step
# MAE for + 9: 3,469
# 2/2 [==============================] - 0s 21ms/step
# MAE for + 10: 3,600
# 2/2 [==============================] - 0s 19ms/step
# MAE for + 11: 3,973
# 2/2 [==============================] - 0s 19ms/step
# MAE for + 12: 4,315
# 2/2 [==============================] - 0s 27ms/step
# ...

# %% [markdown]
# Este modelo é mais pesado do LSTM normal! temos mais de 10K de parâmetros treináveis.
#
# O LSTM de ordem invertida tem um desempenho muito melhor do LSTM normal,
# indicando que, nesse caso, o processamento cronológico não é importante para o sucesso da abordagem.
#
# Conforme os resultados mostra, temos um modelo muito melhor! Atingimos um MAE em teste **R$ 733.67 em média**. Assim como, MAE de teste de (805.71) é uma redução (diminuição) de 63% entorno do MAE de teste do LSTM (2.191,72). Em outros termos, 805.71 reais é uma diminuição de 63% de 2.191,72 reais (melhoria de 63% em relação à model LSTM). Pode-se então, comprovar que este modelo apresenta resultados significativos de assertividade em relação ao first the model, pois suas estimativas são significativas.
#
# Além do mais, MAPE afirma que as previsões do nosso modelo estão erradas, **em média, 9,4% abaixo do valor real**.
#
# Reference:
#
# <a href="https://www.calculator.net/percent-calculator.html?c3par1=2.62&c3par2=2.39&ctype=3&x=43&y=28#pctdifferencehttps://www.calculator.net/percent-calculator.html?c3par1=2.62&c3par2=2.39&ctype=3&x=43&y=28#pctdifference" target ="_bank">Percentage Calculator</a>
#
# ---

# %% [markdown]
# ### 6.3. Model GRU Stacking recurrent layers using method Seq2Seq

# %%
# Resets all state generated by Keras.
tf.keras.backend.clear_session()

# Ensures reproducibility
tf.random.set_seed(42)

# Define a sequential model
gru_seq2seq= tf.keras.models.Sequential([
      tf.keras.Input(shape=[SEQ_LENGTH, NUM_FEATURES]),
      tf.keras.layers.GRU(32, return_sequences=True, unroll=True),
      #tf.keras.layers.GRU(64, return_sequences=True, unroll=True),
      #tf.keras.layers.GRU(96, return_sequences=True, unroll=True),
      tf.keras.layers.Dense(14),
]) 
# Model summary
gru_seq2seq.summary()

# Train the model
fit_and_evaluate(model=gru_seq2seq, 
                 train_set=seq2seq_train, 
                 valid_set=seq2seq_valid,
                 learning_rate=1e-3,
                 epochs=1000,
                 logdir="gru",
                 filepath="models/gru_seq2seq.h5",
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  gru (GRU)                   (None, 49, 32)            3744
#
#  dense (Dense)               (None, 49, 14)            462
#
# ...
# Total params: 4,206
# Trainable params: 4,206
# Non-trainable params: 0
# _________________________________________________________________
# 0epoch [00:00, ?epoch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_train_batch_end` time: 0.0425s). Check your callbacks.
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5192e-06 - mae: 0.0014 - mape: 16.7224 - mse: 3.0383e-06 - msle: 2.9804e-06
#   Metrics  Score
# 0    loss   0.00
# 1     mae   0.00
# 2    mape  16.72
# 3     mse   0.00
# 4    msle   0.00

# %%
# Evaluate the model
predictions(model=gru_seq2seq,
           dataset_valid=mulvar_valid,
           dataset_test = mulvar_test,
           target='total_sales_per_day',
           seq2seq_valid=seq2seq_valid,
           seq2seq_test = seq2seq_test,
           ahead=14,
)
# Out:
# Forecast in Data Validation
# 2/2 [==============================] - 1s 31ms/step
# MAE for + 1: 1,919
# 2/2 [==============================] - 0s 24ms/step
# MAE for + 2: 1,814
# 2/2 [==============================] - 0s 42ms/step
# MAE for + 3: 1,837
# 2/2 [==============================] - 0s 51ms/step
# MAE for + 4: 2,084
# 2/2 [==============================] - 0s 46ms/step
# MAE for + 5: 2,060
# 2/2 [==============================] - 0s 50ms/step
# MAE for + 6: 2,128
# 2/2 [==============================] - 0s 24ms/step
# MAE for + 7: 2,406
# 2/2 [==============================] - 0s 26ms/step
# MAE for + 8: 2,211
# 2/2 [==============================] - 0s 26ms/step
# MAE for + 9: 2,700
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 10: 2,561
# 2/2 [==============================] - 0s 24ms/step
# MAE for + 11: 3,088
# 2/2 [==============================] - 0s 26ms/step
# MAE for + 12: 3,156
# 2/2 [==============================] - 0s 35ms/step
# ...

# %% [markdown]
# ### WaveNet

# %%
# Resets all state generated by Keras.
tf.keras.backend.clear_session()

# Ensures reproducibility
tf.random.set_seed(42)

# Define a sequential model
wavenet_model = tf.keras.models.Sequential([tf.keras.Input(shape=[SEQ_LENGTH, NUM_FEATURES]),
]) 

for rate in (1, 2, 4, 8) * 2:
    wavenet_model.add(tf.keras.layers.Conv1D(
        filters=32, kernel_size=2, padding="causal", activation="relu",
        dilation_rate=rate))
    
wavenet_model.add(tf.keras.layers.Conv1D(filters=14, kernel_size=1))

longer_train = to_seq2seq_dataset(mulvar_train,ahead=14, shuffle=True, seed=42)

longer_valid = to_seq2seq_dataset(mulvar_valid, ahead=14)

downsampled_train = longer_train.map(lambda X, Y: (X, Y[:, 3::2]))
downsampled_valid = longer_valid.map(lambda X, Y: (X, Y[:, 3::2]))

# Model summary
wavenet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 49, 32)            352
#
#  conv1d_1 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_2 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_3 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_4 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_5 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_6 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_7 (Conv1D)           (None, 49, 32)            2080
#
#  conv1d_8 (Conv1D)           (None, 49, 14)            462
#
# ...
# Total params: 15,374
# Trainable params: 15,374
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
fit_and_evaluate(model=wavenet_model, 
                 train_set=longer_train, 
                 valid_set=longer_valid,
                 learning_rate=1e-3,
                 epochs=1000,
                 logdir="wavenet",
                 filepath="models/wavenet.h5",
)
# Out:
# 0epoch [00:00, ?epoch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0036s vs `on_train_batch_end` time: 0.0115s). Check your callbacks.
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9065e-06 - mae: 0.0015 - mape: 16.5438 - mse: 3.8131e-06 - msle: 3.7362e-06
#   Metrics  Score
# 0    loss   0.00
# 1     mae   0.00
# 2    mape  16.54
# 3     mse   0.00
# 4    msle   0.00

# %%
# Evaluate the model
predictions(model=wavenet_model,
           dataset_valid=mulvar_valid,
           dataset_test = mulvar_test,
           target='total_sales_per_day',
           seq2seq_valid=seq2seq_valid,
           seq2seq_test = seq2seq_test,
           ahead=14,
)
# Out:
# Forecast in Data Validation
# 2/2 [==============================] - 0s 16ms/step
# MAE for + 1: 1,767
# 2/2 [==============================] - 0s 14ms/step
# MAE for + 2: 1,667
# 2/2 [==============================] - 0s 15ms/step
# MAE for + 3: 2,535
# 2/2 [==============================] - 0s 16ms/step
# MAE for + 4: 2,066
# 2/2 [==============================] - 0s 14ms/step
# MAE for + 5: 1,740
# 2/2 [==============================] - 0s 15ms/step
# MAE for + 6: 2,248
# 2/2 [==============================] - 0s 18ms/step
# MAE for + 7: 2,867
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 8: 2,876
# 2/2 [==============================] - 0s 18ms/step
# MAE for + 9: 2,342
# 2/2 [==============================] - 0s 15ms/step
# MAE for + 10: 2,354
# 2/2 [==============================] - 0s 16ms/step
# MAE for + 11: 2,249
# 2/2 [==============================] - 0s 20ms/step
# MAE for + 12: 3,109
# 2/2 [==============================] - 0s 18ms/step
# ...

# %% [markdown]
# Let's load the tensorboard Jupyter extension and start the TensorBoard server:

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./world_of_comics_logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-493866233a2dc473" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-493866233a2dc473");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### 6.4. Comparisons between Models on validation data

# %% [markdown]
# ![image.png](attachment:dfa5e3f4-83be-466a-aca4-432d092b50f9.png)

# %% [markdown]
# ### 6.5. Selecting the best model to Deploy

# %% [markdown]
# ### 6.5.1. Model BI-LSTM with Triangular structure recurrent layers using method Seq2Seq

# %% [markdown]
# Como o conjunto de dados neste projeto é pequeno, arquitetura BI-LSTM com menos camadas provavelmente terá capacidade suficiente para aprender os dados e evitar o overfitting. No entanto, vamos construir nosso modelo para deploly usando a estrutura triangulares, ou seja, 3 camadas múltiplas de 32, conforme a figura ilustra.
#
# Além do mais, consulte livro: Automated Machine Learning in Action para aprender mais sobre Customizing the search space by creating AutoML pipelines.
#
# ![image.png](attachment:e84daf74-0177-4419-85f1-010f85389d74.png)
#
# > Source: (QINGQUAN.S; HAIFENG.J; X.HU, 2022)

# %% [markdown]
# ### 6.2. Model training for Deploly

# %%
# Split Tran/Test
seq2seq_train_deploy = to_seq2seq_dataset(mulvar_train,ahead=5, shuffle=True, seed=42).cache()
seq2seq_valid_deploy = to_seq2seq_dataset(mulvar_valid,ahead=5).cache()
seq2seq_test_deploy  = to_seq2seq_dataset(mulvar_test, ahead=5).cache()

# Resets all state generated by Keras.
tf.keras.backend.clear_session()

# Ensures reproducibility
tf.random.set_seed(42)

'''
# Define a sequential model
lstm_seq2seq= tf.keras.models.Sequential([
      #tf.keras.Input(shape=[None, NUM_FEATURES]),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(1024, return_sequences=True, unroll=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(512, return_sequences=True, unroll=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, return_sequences=True, unroll=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True, unroll=True)),
      tf.keras.layers.Dense(7), # no activation function by default
]) 
'''

# Define a sequential model
lstm_bi_seq2seq_deploy = tf.keras.models.Sequential([
      tf.keras.Input(shape=[SEQ_LENGTH, NUM_FEATURES]),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, unroll=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, unroll=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(96, return_sequences=True, unroll=True)),
      tf.keras.layers.Dense(5),
]) 
# Model summary
lstm_bi_seq2seq_deploy.summary()

# Train the model for deploy 
fit_and_evaluate(model=lstm_bi_seq2seq_deploy, 
                 train_set=seq2seq_train_deploy, 
                 valid_set=seq2seq_valid_deploy,
                 learning_rate=1e-3,
                 epochs=1000,
                 logdir="lstm_bi_deploy",
                 filepath="models/lstm_bi_seq2seq_deploy.h5"
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  bidirectional (Bidirectiona  (None, 49, 64)           9728
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 49, 128)          66048
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 49, 192)          172800
#  nal)
#
#  dense (Dense)               (None, 49, 5)             965
#
# ...
# Total params: 249,541
# Trainable params: 249,541
# Non-trainable params: 0
# _________________________________________________________________
# 0epoch [00:00, ?epoch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0226s vs `on_train_batch_end` time: 0.1474s). Check your callbacks.
# 6/6 [==============================] - 0s 10ms/step - loss: 1.2248e-07 - mae: 3.4720e-04 - mape: 4.2072 - mse: 2.4495e-07 - msle: 2.4047e-07
#   Metrics  Score
# 0    loss   0.00
# 1     mae   0.00
# ...

# %%
# View last the five registros before predict 
mulvar_test.tail() * SN
# Out:
#             discount    SMA_5    SMA_3  total_sales_per_hour  total_sales_per_day
# date
# 2020-01-27      0.10 2,991.49 2,666.16              3,336.48             3,336.48
# 2020-01-28      0.10 2,882.63 3,256.26              4,420.08             4,420.08
# 2020-01-29      0.10 3,151.01 3,501.54              2,800.98             2,800.98
# 2020-01-30      0.10 3,397.97 3,519.18              4,001.76             4,001.76
# 2020-01-31      0.10 3,461.47 3,740.94              2,564.10             2,564.10

# %%
# Evaluate the model
predictions(model =lstm_bi_seq2seq_deploy,
           dataset_valid=mulvar_valid,
           dataset_test= mulvar_test,
           target='total_sales_per_day',
           seq2seq_valid= seq2seq_valid_deploy,
           seq2seq_test= seq2seq_test_deploy,
           ahead=5,
)
# Out:
# Forecast in Data Validation
# 6/6 [==============================] - 0s 27ms/step
# MAE for + 1: 1,998
# 6/6 [==============================] - 0s 13ms/step
# MAE for + 2: 2,166
# 6/6 [==============================] - 0s 15ms/step
# MAE for + 3: 2,388
# 6/6 [==============================] - 0s 10ms/step
# MAE for + 4: 2,632
# 6/6 [==============================] - 0s 11ms/step
# MAE for + 5: 2,993
#
#
# Forecast in Data Test
# 6/6 [==============================] - 0s 12ms/step
# MAE for +1: 2,409
# 6/6 [==============================] - 0s 12ms/step
# MAE for +2: 2,615
# 6/6 [==============================] - 0s 11ms/step
# MAE for +3: 2,651
# 6/6 [==============================] - 0s 12ms/step
# MAE for +4: 2,795
# 6/6 [==============================] - 0s 11ms/step
# MAE for +5: 3,254
# ...
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7572e-07 - mae: 4.3239e-04 - mape: 4.6890 - mse: 3.5144e-07 - msle: 3.4426e-07
# ...

# %% [markdown]
# ![image.png](attachment:2604a694-031c-4ddf-b3eb-847fc4e3e7f1.png)

# %% [markdown]
# ### 6.3. Forecast

# %% [markdown]
# Ressalta-se que, a previsão refere-se à comparação do **valor previsto pelo modelo com o valor real**, isto é previsão (predict). Por outro lado, o **forecast** é quando você prevê o futuro, ou seja, você não tem o verdadeiro valor do futuro, no melhor sentido, você não sabe o valor do futuro, ao qual você só tem o modelo, bem como, você tem a garantia que está usando o melhor modelo para forecast.

# %%
# Predictions
X_pred_deploy = mulvar_test.to_numpy()[np.newaxis, :SEQ_LENGTH]

# Create an range of date
date_range =[mulvar_test.index[-1] + datetime.timedelta(days=x) for x in range(6)]

# Create new dataframe with the predict
forecast =pd.DataFrame(lstm_bi_seq2seq_deploy.predict(X_pred_deploy)[0, -1]  * 1e6, index=date_range[1:], columns=['Forecast total sales per day for the next 5 days'])

# Calcule a difference
fm, om = np.sum(forecast) / len(forecast), temp.mean()
diff = pd.DataFrame({'forecast_mean':fm, 
                     'original_mean': om,
                     'diff': abs(fm - om)
                    })
# View predict
forecast
# Out:
# 1/1 [==============================] - 0s 73ms/step
#             Forecast total sales per day for the next 5 days
# 2020-02-01                                         13,514.98
# 2020-02-02                                         13,185.17
# 2020-02-03                                         12,895.90
# 2020-02-04                                         12,432.31
# 2020-02-05                                         12,406.05

# %%
# View difference
diff
# Out:
#                                                   forecast_mean  original_mean     diff
# Forecast total sales per day for the next 5 days      12,886.88       9,842.21 3,044.67

# %% [markdown]
# MAE for +1: 2,409 à MAE for +5: 3,254, ou seja, erro em média da previsão MAE em teste,  está aproximadamente contido a este intervalo da diferença das médias reais com as prevista do modelo.

# %% [markdown]
# ### 6.3.1. CI for the expected value of Y

# %% [markdown]
# Em alguns casos, essa estimativa atual do erro de generalização não será suficiente para convencê-lo? Você pode querer ter uma ideia de quão precisa é essa estimativa. Para isso, vamos calcular CI de 95% para o erro de generalização usando scipy.stats.t.interval().
#
# - O objetivo de um modelo de aprendizado de máquina é generalizar: executar com precisão em dados de entradas nunca antes vistas. É mais difícil do que parece.
#
# Em poucas palavras, o objetivo é estimar o valor esperado de Y de um modelo de regressão linear na população condicionado ao valor Xi do regresso.
#
# A função a seguir implementa calcule CI de 95% para erro MAE

# %%
# calculate confidence interval for the MAE
def ci_MAE(y_pred, y_test, confidence = None):

    # Capture absolute error
    abs_errors = abs(y_pred - y_test) 
    
    # return CI
    return stats.t.interval(confidence, len(abs_errors) - 1, loc=abs_errors.mean(),scale=stats.sem(abs_errors))

# %%
# Capture forecast values for a 5 day window
y_pred, y_test =lstm_bi_seq2seq_deploy.predict(X_pred_deploy)[0, -1] * 1e6, X_pred_deploy[0, -1] 

# Function call 
ci_MAE(y_pred,y_test,.95)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# (12290.933448733751, 13482.814112948392)

# %% [markdown]
# ### Indicadores
#
# De acordo com resultados apresentados, temos um CI de 95% de forecast que **varia de R$ 12,290.93 a 13,482.81 (estimativa forecast) do total de vendas por dia de toys**, ou seja, seria uma estimativa em repetidas amostras de uma janela de tamanho  (5 dias), conteria em **95%** das situações o valor real médio do **total de vendas por dia de toys**.
#
# Em  poucas palavras, o intervalo de confiança de **95%** para real valor do total de vendas por dia de toys em média das vendas por dia é (12.290.93, 13.482.81).
#
#
# Ainda mais, MAPE afirma que as previsões do nosso modelo estão erradas, **em média, 4,4% abaixo do valor real**.
#
# Em resumo, os valores previstos pelo nosso modelo para os próximos 5 dias varia de **R$ (12,406.05 a 13,514.98)**, consequentemente muito similar do nosso **CI de 95%**. Pode-se então, finalmente, verificar que  as estimativas do nosso modelo e do **CI de 95%** são relativamente significativas aplicando-se este tipo teste de comparação.

# %% [markdown]
# ---
#
# *References*
#
# Applied Deep Learning
#
# https://www.datascienceacademy.com.br/
#
# Deep Learning A Practitioner’s Approach, 2E
#
# Deep Learning with Python, 2E
#
# Hands-on: Machine Learning with Scikit-Learn & TensorFlow, 3E
#
# Practical Time Series Analysis: Prediction with Statistics and Machine Learning
#
# Machine Learning: Guia de Referência Rápida
#
# Organizações Exponenciais: Por que elas são 10 vezes melhores, mais rápidas e mais baratas que a sua (e o que fazer a respeito)
#
#
# https://www.portent.com/blog/analytics/rolling-averages-math-moron.htm
#
# <a href="https://developers-google-com.translate.goog/machine-learning/crash-course/regularization-for-sparsity/l1-regularization?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=pt-BR&_x_tr_pto=op%2Csc">Regularization for Sparsity: L₁ Regularization</a>
#
# https://github.com/dmlc/xgboost
#
# https://xgboost.readthedocs.io/en/stable/
#
# https://github.com/azminewasi/Kaggle-Notebooks/blob/b1d9e206eb8f811c48098e04a76c836eebed90d5/xgboost-wrangling-with-hyperparameters-guide.ipynb
#
# https://www.nvidia.com/en-us/glossary/data-science/xgboost/
#
# https://towardsdatascience.com/https-medium-com-vishalmorde-xgboost-algorithm-long-she-may-rein-edd9f99be63d
#
# https://www.scikit-yb.org/en/latest/api/classifier/threshold.html?highlight=Discrimination%20threshold#yellowbrick.classifier.threshold.discrimination_threshold
#
# https://atsa-es.github.io/atsa-labs/sec-boxjenkins-aug-dickey-fuller.html
#
#
# https://atsa-es.github.io/atsa/Labs/Week%202/HW_2_box-jenkins_Key.html
#
#
#
# https://365datascience.com/tutorials/statistics-tutorials/standardization/
#
# https://www-analyticsvidhya-com.translate.goog/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=en-US&_x_tr_pto=nui,op,sc
#
# https://machinelearningmastery-com.translate.goog/standardscaler-and-minmaxscaler-transforms-in-python/?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=en-US&_x_tr_pto=op,sc
#
#
# https://www.geeksforgeeks.org/normalization-vs-standardization/
#
#
# https://towardsdatascience.com/normalization-vs-standardization-quantitative-analysis-a91e8a79cebf#:~:text=Normalization%20typically%20means%20rescales%20the,we%20always%20scale%20our%20features%3F
#
#
#
# https://stats-stackexchange-com.translate.goog/questions/10289/whats-the-difference-between-normalization-and-standardization?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=pt-BR&_x_tr_pto=sc
#
#
# https://iq-opengenus-org.translate.goog/standardization-regularization-vs-normalization/?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=pt-BR&_x_tr_pto=sc
#
# https://www.mathsisfun.com/data/standard-deviation-formulas.html
